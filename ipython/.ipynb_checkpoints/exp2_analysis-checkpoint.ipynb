# %% [markdown]
# # Experiment 2 Analysis
#
# Code to visualize results from Experiment 2, including text analysis.

# %%
import itertools
import string
import random

import numpy as np
import pandas as pd

import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud

import seaborn as sns
import matplotlib
import matplotlib.pylab as plt

matplotlib.rcParams['font.sans-serif'] = "Arial"
matplotlib.rcParams['font.family'] = "sans-serif"

hp = sns.cubehelix_palette(n_colors=4, rot=.5)
plot_palette = [hp[3], hp[1]]

# %% [markdown]
# ## Learner Concept Knowledge

# %%
teacher_joined_survey = pd.read_csv("data/exp2_for_visualization.csv")
teacher_joined_survey.rename(columns={"visibility":"Context"}, inplace=True)

final_level = teacher_joined_survey[teacher_joined_survey.level_number == 10]

# %%
final_level.sort_values(["comm_viz"], inplace=True)

plt.figure(figsize=(4, 4))
final_level["size"] = 3000

ax = sns.lineplot(x="boolean_complexity", y="learner_concept", hue='communication', style='Context', data=final_level, 
                  err_style="bars", err_kws={"capsize": 10, "capthick": 2.5, "linewidth": 2.5}, ci=95, 
                  linewidth=5, alpha=.9, palette=plot_palette)

plt.ylabel("Learner Concept Knowledge")
plt.xlabel("Concept Complexity")

for x in [.25, .5, .75]:
    ax.axhline(x, alpha=.2, linestyle='--', c='k')
    
plt.yticks([0, .25, .5, .75, 1])
plt.ylim(0, 1)

ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=11.5)

plt.xticks([1, 4], labels=["Low (1)", "Intermediate (4)"])
plt.xlim(.5, 4.5)

plt.legend(prop={'size': 15, 'weight': 'bold'})
plt.gca().legend().remove()
# Out:
# /Users/sumers/opt/anaconda3/envs/jupyter/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# /Users/sumers/opt/anaconda3/envs/jupyter/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
final_level.groupby(["boolean_complexity", "communication", "Context"]).learner_concept.describe()
# Out:
#                                           count      mean       std   min  \
# boolean_complexity communication Context
# 1                  chat          full      35.0  0.842857  0.252456  0.00
#                                  partial   33.0  0.715909  0.352548  0.00
#                    demo          full      39.0  0.852564  0.256289  0.25
#                                  partial   34.0  0.757353  0.386737  0.00
# 4                  chat          full      38.0  0.822368  0.285683  0.00
#                                  partial   35.0  0.400000  0.326242  0.00
#                    demo          full      33.0  0.393939  0.341071  0.00
#                                  partial   37.0  0.429054  0.370974  0.00
#
#                                               25%    50%     75%  max
# boolean_complexity communication Context
# 1                  chat          full     0.62500  1.000  1.0000  1.0
#                                  partial  0.50000  1.000  1.0000  1.0
#                    demo          full     0.75000  1.000  1.0000  1.0
#                                  partial  0.56250  1.000  1.0000  1.0
# 4                  chat          full     0.65625  1.000  1.0000  1.0
#                                  partial  0.12500  0.375  0.6875  1.0
#                    demo          full     0.12500  0.375  0.6250  1.0
#                                  partial  0.00000  0.375  0.7500  1.0

# %% [markdown]
# ## Player Scores

# %%
plt.figure(figsize=(4,4))

ax = sns.lineplot(data=final_level.sort_values(['Context', "communication", "boolean_complexity"], ascending=True), 
                  x="boolean_complexity", y='cum_player_score', 
                  hue='communication', style="Context", alpha=.9,
                  err_style="bars", err_kws={"capsize": 10, "capthick": 2.5, "linewidth": 2.5}, ci=95, 
                  linewidth=5, palette=plot_palette)

for score in [10, 20, 30]:
    plt.axhline(score, linestyle="--", c='k', alpha=.2, linewidth=2)

plt.ylabel("Learner Scores")
plt.xlabel("Concept Complexity")

ax.xaxis.label.set_size(15)
ax.yaxis.label.set_size(15)
ax.tick_params(axis='both', which='major', labelsize=11.5)

plt.ylim(0, 40)
plt.xlim(0.5, 6.5)

plt.xticks([1, 4], labels=["Low (1)", "Intermediate (4)"])
plt.xlim(.5, 4.5)

plt.gca().legend().remove()
plt.show()

# %%
sorted_full = teacher_joined_survey.sort_values(['Context', "communication"], ascending=True)

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

plot_titles = ["Low", "Intermediate"]

sorted_full["communication"] = sorted_full.communication.apply(lambda x: "Language" if x == "chat" else "Demonstration")
sorted_full["Context"] = sorted_full.Context.apply(lambda x: "Full" if x == "full" else "Partial")


for ax, concept in zip(axs.reshape(-1), [1, 2]): 
    to_plot = sorted_full[sorted_full.concept_number == concept]

    sns.lineplot(data=to_plot, x='level_number', y="pct_max_score", hue='communication', style="Context", 
         sort=False, marker='o',
         err_style="bars", err_kws={"capsize": 10}, palette=plot_palette,
         ci=95, linewidth=5, alpha=.7, ax=ax)

    ax.set_title("{}".format(plot_titles[concept-1]))
    ax.set_ylabel("")
    ax.set_xlabel("Level Number")
        
    for x in [0, 20, 40, 60, 80]:
        ax.axhline(x, alpha=.1, c='k')
    ax.set_ylim(-20, 100)
    ax.set_xticks(range(1,11))
    
    axs.reshape(-1)[0].set_ylabel("Per-Level Normalized Score")

# %%
final_level.groupby(["boolean_complexity", "communication", "Context"]).cum_player_score.describe()
# Out:
#                                           count       mean        std   min  \
# boolean_complexity communication Context
# 1                  chat          full      35.0  32.057143   9.761698   0.0
#                                  partial   33.0  17.181818  16.358206 -15.0
#                    demo          full      39.0  26.512821  12.828570  -2.0
#                                  partial   34.0  29.588235  12.458702   3.0
# 4                  chat          full      38.0  22.026316  11.039210   3.0
#                                  partial   35.0   5.914286  10.207758 -14.0
#                    demo          full      33.0   8.878788  12.810537  -9.0
#                                  partial   37.0   8.270270  12.289672 -17.0
#
#                                            25%   50%   75%   max
# boolean_complexity communication Context
# 1                  chat          full     28.0  36.0  38.0  43.0
#                                  partial   5.0  25.0  29.0  43.0
#                    demo          full     20.5  33.0  36.0  41.0
#                                  partial  25.0  35.0  39.0  42.0
# 4                  chat          full     13.0  21.0  31.5  40.0
#                                  partial  -2.0   5.0  10.0  31.0
#                    demo          full      1.0   7.0  11.0  42.0
#                                  partial  -1.0   5.0  18.0  37.0

# %% [markdown]
# ## Subjective Difficulty

# %%
plt.figure(figsize=(8, 4))

teacher = final_level[["difficulty_teacher", "concept_number", "comm_viz"]]
teacher = teacher.rename(columns={"difficulty_teacher":"difficulty"})
learner = final_level[["difficulty", "concept_number", "comm_viz"]]
teacher["player"] = "teacher"
learner["player"] = "learner"

joined = pd.concat([teacher, learner])
joined.difficulty = 6 - joined.difficulty

linguistic_palette = [hp[3], hp[2]]
demo_palette = [hp[1], hp[0]]

ax = sns.catplot(data=joined, x="comm_viz", y="difficulty", hue="player", col="concept_number", 
                 hatch="/", edgecolor='w', 
                 palette=linguistic_palette,
#                  palette=demo_palette,
                 kind='bar')
# Out:
# /Users/sumers/opt/anaconda3/envs/jupyter/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
joined.groupby(["concept_number", "comm_viz", "player"]).difficulty.describe()
# Out:
#                                      count      mean       std  min  25%  50%  \
# concept_number comm_viz     player
# 1              chat|full    learner   35.0  1.400000  1.287953  0.0  0.0  1.0
#                             teacher   35.0  1.142857  1.216138  0.0  0.0  1.0
#                chat|partial learner   33.0  2.454545  1.501893  0.0  1.0  3.0
#                             teacher   33.0  2.212121  1.672528  0.0  1.0  2.0
#                demo|full    learner   39.0  1.871795  1.239259  0.0  1.0  2.0
#                             teacher   39.0  1.384615  1.161111  0.0  0.5  1.0
#                demo|partial learner   34.0  1.647059  1.299938  0.0  1.0  2.0
#                             teacher   34.0  1.029412  1.058452  0.0  0.0  1.0
# 2              chat|full    learner   38.0  1.868421  1.579789  0.0  1.0  1.0
#                             teacher   38.0  1.657895  1.300235  0.0  1.0  1.5
#                chat|partial learner   35.0  3.571429  1.144956  1.0  3.0  4.0
#                             teacher   35.0  3.685714  1.450587  0.0  3.0  4.0
#                demo|full    learner   33.0  3.545455  1.325021  0.0  3.0  4.0
#                             teacher   33.0  2.121212  1.293193  0.0  2.0  2.0
#                demo|partial learner   37.0  3.648649  1.206837  0.0  3.0  4.0
#                             teacher   37.0  1.702703  1.288084  0.0  1.0  2.0
#
#                                       75%  max
# concept_number comm_viz     player
# 1              chat|full    learner  2.00  5.0
#                             teacher  2.00  5.0
#                chat|partial learner  4.00  5.0
#                             teacher  4.00  5.0
#                demo|full    learner  3.00  5.0
#                             teacher  2.00  4.0
#                demo|partial learner  2.00  4.0
#                             teacher  2.00  4.0
# 2              chat|full    learner  3.00  5.0
#                             teacher  2.75  5.0
#                chat|partial learner  4.50  5.0
#                             teacher  5.00  5.0
#                demo|full    learner  4.00  5.0
#                             teacher  3.00  5.0
#                demo|partial learner  5.00  5.0
#                             teacher  3.00  4.0

# %%
joined["group"] = joined.apply(lambda x: "{}|{}".format(x["comm_viz"], x["player"]), axis=1)
joined["group"] = joined.group.str.replace("chat", "lang")

# %%
export_to_r_cols = ["group", "difficulty", "concept_number"]

joined[export_to_r_cols].to_csv("data/exp2_survey_difficulty_for_r.csv")

# %% [markdown]
# # Behavioral Analysis

# %% [markdown]
# ## Linguistic Teaching

# %%
chat_games = teacher_joined_survey[teacher_joined_survey.communication == "chat"]
chat_games.chat_text = chat_games.chat_text.apply(str)

chat_df_records = []
for k, g in chat_games.groupby("task_uuid"):
    chat_df_records.append({"task_uuid": str(k), "all_chat": g.chat_text.str.cat(sep="\n\t")})
    
cumulative_chat = pd.DataFrame.from_records(chat_df_records)
final_chat = chat_games[chat_games.level_number == 10].set_index("task_uuid").merge(cumulative_chat, on="task_uuid")
# Out:
# /Users/sumers/opt/anaconda3/envs/jupyter/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
sns.barplot(data=final_chat, y="cum_teacher_chat", x="concept_number", hue="Context", 
            palette=plot_palette)

plt.ylabel("Total Characters Sent")
plt.xlabel("Concept Complexity")

plt.xticks([0, 1], labels=["Low (1)", "Intermediate (4)"])
plt.ylim(0, 810)
plt.suptitle("Total Chat Characters by Context\n(partial context teachers sent more messages)")
# Out:
# Text(0.5, 0.98, 'Total Chat Characters by Context\n(partial context teachers sent more messages)')

# %% [markdown]
# ### Token / Bigram Statistics

# %%
def chat_blob_to_tokens(chat_blob, lemmatize=True, stopword_filter=True):
    
    # Remove punctuation
    chat_blob = chat_blob.replace("|", " ").lower()
    chat_blob = chat_blob.translate(str.maketrans('', '', string.punctuation))
    
    chat_tokens = nltk.word_tokenize(chat_blob)
    
    # Convert single-digit numerals to words, i.e. "0" --> "zero"
    number_map = {"0":"zero","1":"one","2":"two","3":"three", 
                "4": "four","5":"five", "6": "six", "7":"seven", "8":"eight", "9":"nine"}

    chat_tokens = [number_map.get(t, t) for t in chat_tokens]

    return chat_tokens
    
def filter_and_lemmatize(chat_tokens):
    
    # Stem or lemmaize the words
    chat_tokens = [nltk.stem.WordNetLemmatizer().lemmatize(word) for word in chat_tokens]
    
    all_stopwords = stopwords.words("english")
    
    chat_tokens = [t for t in chat_tokens if t not in all_stopwords]
        
    return chat_tokens

# %%
final_chat["tokens"] = final_chat.apply(lambda x: filter_and_lemmatize(chat_blob_to_tokens(x["all_chat"])), axis=1)

# %%
token_count_df_list = []
for k, g in final_chat.groupby("comm_viz"):
    
    all_tokens = pd.Series(itertools.chain.from_iterable(g.tokens))
    token_count_df = pd.DataFrame(all_tokens.value_counts()).reset_index()
    token_count_df = token_count_df.rename(columns={"index": "word", 0: "word_count"})
    token_count_df["comm_viz"] = k
    token_count_df["percent"] = 100 * token_count_df["word_count"] / token_count_df["word_count"].sum()
    token_count_df_list.append(token_count_df)
    
language_df = pd.concat(token_count_df_list)

# %%
full_chat = language_df[language_df["comm_viz"].str.contains("full")]
full_chat.loc[:, "cum_percent"] = full_chat.percent.cumsum()
full_chat.sort_values("percent", ascending=False)[:10]
# Out:
# /Users/sumers/opt/anaconda3/envs/jupyter/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#        word  word_count   comm_viz   percent  cum_percent
# 0  triangle         146  chat|full  5.005142     5.005142
# 1      good         145  chat|full  4.970860     9.976003
# 2    square         138  chat|full  4.730888    14.706891
# 3      pink         105  chat|full  3.599589    18.306479
# 4       job          94  chat|full  3.222489    21.528968
# 5     great          93  chat|full  3.188207    24.717175
# 6      blue          91  chat|full  3.119643    27.836819
# 7       one          71  chat|full  2.434008    30.270826
# 8    filled          64  chat|full  2.194035    32.464861
# 9  positive          63  chat|full  2.159753    34.624614

# %%
partial_chat = language_df[language_df["comm_viz"].str.contains("partial")]
partial_chat.loc[:, "cum_percent"] = full_chat.percent.cumsum()
partial_chat.sort_values("percent", ascending=False)[:10]
# Out:
# /Users/sumers/opt/anaconda3/envs/jupyter/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#        word  word_count      comm_viz   percent  cum_percent
# 0       one         279  chat|partial  6.204136     5.005142
# 1     right         268  chat|partial  5.959529     9.976003
# 2      left         251  chat|partial  5.581499    14.706891
# 3    bottom         246  chat|partial  5.470314    18.306479
# 4  positive         244  chat|partial  5.425839    21.528968
# 5       top         227  chat|partial  5.047810    24.717175
# 6    corner         183  chat|partial  4.069380    27.836819
# 7  negative         172  chat|partial  3.824772    30.270826
# 8        wa         127  chat|partial  2.824105    32.464861
# 9      good          97  chat|partial  2.156994    34.624614

# %%
final_chat["bigrams"] = final_chat.apply(lambda x: nltk.bigrams(filter_and_lemmatize(chat_blob_to_tokens(x["all_chat"]))), axis=1)

bigram_df_list = []
for k, g in final_chat.groupby("comm_viz"):
    
    all_bigrams = pd.Series(itertools.chain.from_iterable(g.bigrams))
    bigram_count_df = pd.DataFrame(all_bigrams.value_counts()).reset_index()
    bigram_count_df = bigram_count_df.rename(columns={"index": "bigram", 0: "bigram_count"})
    bigram_count_df["condition"] = k
    bigram_count_df["percent"] = 100 * bigram_count_df["bigram_count"] / bigram_count_df["bigram_count"].sum()
    bigram_df_list.append(bigram_count_df)

bigram_df = pd.concat(bigram_df_list)

partial_bigrams = bigram_df[bigram_df.condition.str.contains("partial")]
partial_bigrams.sort_values("bigram_count", ascending=False).head(10)
# Out:
#                bigram  bigram_count     condition   percent
# 0      (bottom, left)           130  chat|partial  2.935200
# 1        (top, right)           122  chat|partial  2.754572
# 2     (bottom, right)            96  chat|partial  2.167532
# 3         (top, left)            80  chat|partial  1.806277
# 4      (left, corner)            49  chat|partial  1.106345
# 5     (right, corner)            46  chat|partial  1.038609
# 6  (positive, bottom)            40  chat|partial  0.903138
# 7   (right, positive)            33  chat|partial  0.745089
# 8         (good, job)            31  chat|partial  0.699932
# 9  (corner, positive)            29  chat|partial  0.654775

# %%
full_bigrams = bigram_df[bigram_df.condition.str.contains("full")]
full_bigrams.sort_values("bigram_count", ascending=False).head(10)
# Out:
#                  bigram  bigram_count  condition   percent
# 0           (good, job)            47  chat|full  1.652602
# 1          (well, done)            42  chat|full  1.476793
# 2          (great, job)            32  chat|full  1.125176
# 3     (empty, triangle)            30  chat|full  1.054852
# 4        (blue, square)            24  chat|full  0.843882
# 5            (nan, nan)            24  chat|full  0.843882
# 6         (keep, going)            22  chat|full  0.773558
# 7      (pink, triangle)            21  chat|full  0.738397
# 8    (triangle, square)            20  chat|full  0.703235
# 9  (triangle, positive)            18  chat|full  0.632911

# %% [markdown]
# ### Word Clouds

# %%
colors = [(0, 0, 0), (0, 0, 0)]  # R -> G -> B
cmap_name = 'my_list'
cmap = matplotlib.colors.LinearSegmentedColormap.from_list(cmap_name, colors, N=100)

# %%
wc_dict = {}
for k, g in final_chat.groupby("comm_viz"):
    
    all_tokens = list(itertools.chain.from_iterable(g.apply(lambda x: chat_blob_to_tokens(x["all_chat"]), axis=1)))
    random.shuffle(all_tokens)
    string_blob = " ".join(all_tokens)
    wc_dict[k] = WordCloud(max_words=20, max_font_size=50, min_font_size=10, background_color='white', colormap=cmap).generate(string_blob)

plt.figure()
plt.axis("off")
plt.imshow(wc_dict["chat|partial"], interpolation='bilinear')

plt.figure()
plt.axis("off")
plt.imshow(wc_dict["chat|full"],  interpolation='bilinear')

# %% [markdown]
# ### Raw Chat Text

# %%
for k, games in chat_games.groupby("task_uuid"):

        games = games.sort_values(by='level_number')
        print("\nContext: {}, Complexity: {}\nCumulative Score: {}".format(games.iloc[0]["Context"], games.iloc[0]["boolean_complexity"], games.iloc[-1]["cum_player_score"]))
        print("{}".format(k))
        for gid, g in games.iterrows():
            print("Score {} --> \"{}\"".format(g.player_score, g.chat_text.replace("|", " ")))
# Out:
# Context: partial, Complexity: 4
# Cumulative Score: -3
# 5680452cc5767f00121cc81a:610bfd264bc8331f50ceea9a
# Score -3 --> "those shapes are negative points do not choose those next time "
# Score 2 --> "those shapes are postive the shapes you were moving toward at end were negative "
# Score -1 --> "the first shape you chose was negative and second was positive "
# Score -1 --> "the only shape you chose was negative the rest of them in that same corner were all postive   "
# Score 0 --> "all the shapes you were going close to were negative "
# Score 1 --> "the rest of the shapes in that corner you collected from were all negative, the one you chose was the only postive one "
# Score 1 --> "very good, the one you chose was positive, whereas the two you passed between were negative "
# Score -1 --> "the first one you got was postive but other two negative "
# Score 1 --> "the top left corner were all positive "
# Score -2 --> "that corner you got was all negative "
#
# Context: partial, Complexity: 4
# Cumulative Score: 10
# 572f526c3c27e7000e0b8aaa:610c0baf82d664147357ce18
# Score 1 --> "All in the bottom left corner were +1 but the object at the very bottom left"
# Score 2 --> "The one you collected on the left hand side was -1 as well as the one you did not collect"
# Score 0 --> "The second one you collected was -1 and so was the one uncollected in the bottom right corner "
# Score 3 --> "All three you collected were +1, the one directly left of your bot is +1 and the other object is -1 that was uncollected"
# Score 1 --> "The first you collected was -1, the others +1. Every object in the top right on this board is +1"
# Score 1 --> "First two were +1, third and fourth -1, fifth +1"
# Score 1 --> "First one collected was -1 the rest in the bottom left were +1"
# Score 0 --> "First one collected was -1 second collected +1 the two directly below the bot are +1, the rest in bottom left are -1"
# Score 4 --> "Every object in the top left was +1"
# Score -3 --> "4 of those were -1"
#
# Context: full, Complexity: 1
# Cumulative Score: 36
# 5751e9f9eb80c4000741a65d:610c132ec8667ab10b228a6e
# Score -3 --> "The other color is what you should aim for!"
# Score 5 --> "Keep doing what you're doing!"
# Score 4 --> "You're doing great!"
# Score 4 --> "Keep going!"
# Score 5 --> "Good job!"
# Score 3 --> "Awesome!"
# Score 4 --> "Great job!"
# Score 4 --> "Amazing!"
# Score 5 --> "Keep up the good work!"
# Score 5 --> "Fantastic!"
#
# Context: full, Complexity: 4
# Cumulative Score: 19
# 583ec287ad2f4300014b355a:610bf7f2fc28dcbe8a7eb1c5
# Score -1 --> "that was negative solid pinks and hollow blues are positive"
# Score 3 --> "nice nice"
# Score 2 --> "gj"
# Score 2 --> "good good"
# Score 2 --> "gj. that thing moves way too slow lol"
# Score 2 --> "not much to say since the shapes and values aren't changing, at least on my end"
# Score 1 --> "good try"
# Score 2 --> "gj. remember hollow blues are positive too"
# Score 3 --> "yay 3 points"
# Score 3 --> "thus ends the journey of the world's slowest robot"
#
# Context: full, Complexity: 1
# Cumulative Score: 43
# 58ae59babb9e0f0001acb414:610c20c1d546f560ee42d36f
# Score 4 --> "Avoid all pink/purple, you did perfect! "
# Score 5 --> "You've got this exactly. :) "
# Score 4 --> "Good work! "
# Score 4 --> "Perfect! Nice swerve "
# Score 5 --> "Yay, doing so well! "
# Score 3 --> "That was a tricky one, you did really well! "
# Score 4 --> "Nice!! "
# Score 4 --> "You've got it, nice! "
# Score 5 --> "Whoo! So good! "
# Score 5 --> "You did perfectly!! :) "
#
# Context: full, Complexity: 1
# Cumulative Score: 28
# 5927ee603497ad00010171c2:610c25ba66a0ae03b354740a
# Score -3 --> "The squares were positive, triangles negative"
# Score 4 --> "Nice work!"
# Score 4 --> "Doing great"
# Score 4 --> "Keep it up"
# Score 1 --> "Dont forget you can hit two keys at once to move diagonally, which is faster"
# Score 2 --> "There you go"
# Score 3 --> "Nice. Take a second at the start to see which corner has the most value. This one was bottom right."
# Score 3 --> "Very nice"
# Score 5 --> "Perfect! "
# Score 5 --> "Another perfect one. Great job!"
#
# Context: full, Complexity: 4
# Cumulative Score: 9
# 5978f6f009bdcf000153f43d:610c1b9e44eaa906ee1209ac
# Score 2 --> "Go for filled boxes and empty triangles"
# Score 1 --> "Well done "
# Score 1 --> "Great"
# Score 1 --> "Good stuff!"
# Score 1 --> "Good work! "
# Score 0 --> "Good try - hard to move quick enough at times isn't it"
# Score 0 --> "Keep heading for the filled boxes or empty triangles"
# Score 0 --> "how are you feeling?"
# Score 1 --> "Brilliant!"
# Score 2 --> "That's great, well done!"
#
# Context: full, Complexity: 4
# Cumulative Score: 9
# 599da50e17c03c000151b18b:610c258397374b8d0a75d3a3
# Score -2 --> "The blue boxes and pink triangles were negative points but it's okay! "
# Score 1 --> "Good job!! "
# Score 1 --> "Way to go!"
# Score -1 --> "Stay away from the blue boxes and purple triangles!"
# Score 1 --> "Three boxes, nice!"
# Score 2 --> "Nice!!!"
# Score 1 --> "Great!"
# Score 2 --> "So close to three but you're doing great!"
# Score 2 --> "Keep it up!"
# Score 2 --> "Yay, great job!!"
#
# Context: partial, Complexity: 1
# Cumulative Score: 8
# 59bd3c6e3a9ab60001119ae5:610c0badfc8dd2f9b3f6ca85
# Score 3 --> "Always try to move towards the positive number as quickly as possible."
# Score 2 --> "Good job, but always to avoid the negative digits."
# Score 0 --> "The performance was terrible. Better luck next time."
# Score 3 --> "You reacted very slowly. Poor performance. "
# Score 1 --> "The totally tally for this stage is very discouraging. I will suggest you start from your top right hand corner in the next stage."
# Score -3 --> "Yet another terrible performance."
# Score 3 --> "Great improvement. very commendable."
# Score -1 --> "Another disappointing performance. Always aim for the green number, move towards the direction where we have more green numbers."
# Score 4 --> "Great improvement."
# Score -4 --> "I'm a little bit disappointed but then overall you've tried."
#
# Context: full, Complexity: 4
# Cumulative Score: 13
# 59dc458f77860e000151240e:610bf7f5222bf6d078c41663
# Score -3 --> "nan"
# Score 4 --> "nan"
# Score 2 --> "nan"
# Score 2 --> "nan"
# Score -4 --> "Hi "
# Score 1 --> "nan"
# Score 3 --> "nan"
# Score 2 --> "nan"
# Score 3 --> "nan"
# Score 3 --> "nan"
#
# Context: full, Complexity: 1
# Cumulative Score: 25
# 5a1b1091087f2e0001eaf8a3:610c0bac438725052426fd4d
# Score -1 --> "solid shapes are worth points. "
# Score 1 --> "All the filled shapes are worth one point. Those with an outline are worth -1."
# Score 1 --> "Well done. "
# Score 3 --> "Great job. "
# Score 2 --> "I think you can use both arrows at the same time to move diagonally. "
# Score 3 --> "Well done. "
# Score 3 --> "Well done. "
# Score 4 --> "Great job"
# Score 5 --> "Brillaint "
# Score 4 --> "Well done "
#
# Context: partial, Complexity: 4
# Cumulative Score: 4
# 5a8185b8aa46dd00016b80d6:610c1b9fe29a14d494e057d5
# Score -2 --> "sorry, the values change each time "
# Score 3 --> "nan"
# Score -2 --> "values seem to be random each round correct shapes are bottom left group. apart from the shape furthest in the bottom left"
# Score 0 --> "correct shapes are all top right group, apart from the shape closest to where you started. maybe make a note of shapes and colours so you know which are correct?"
# Score 3 --> "all top right shapes scored. also the two bottom shapes on the right side gave points good job:)"
# Score -4 --> "correct shapes were the last one remaining on the top right, the two middle shapes on top left, and the shape on the far left of the bottom left group"
# Score -2 --> "nan"
# Score 1 --> "two remaining shapes on bottom right scored points. and the two shapes at the top of the bottom left group scored points"
# Score 3 --> "all top left scored points. middle of bottom left scored points. top right of the bottom right group scored points"
# Score 4 --> "all top right scored points, 4/5 top left scored points"
#
# Context: partial, Complexity: 4
# Cumulative Score: -2
# 5b6f3423857ca30001af2637:610c1cbd296a2b079a25b12e
# Score 0 --> "bottom left all but the one in the corner "
# Score 0 --> "you were in the right corner all were okay "
# Score -2 --> "thats okay, next round just go for it - most corners have a mix  "
# Score 1 --> "Well done! try the top right next time "
# Score 1 --> "Yay! keep going!"
# Score 0 --> "Be sure to move your person! try bottom right?"
# Score -1 --> "okay, try again  "
# Score 2 --> "Great! keep going!!  "
# Score -2 --> "Try the bottom ones again, where you just were "
# Score -1 --> "ah they stayed the same! my bad "
#
# Context: full, Complexity: 1
# Cumulative Score: 38
# 5b6f5150410d9d0001a551e4:610bf7f18af3462bb5915764
# Score 2 --> "turqoise good"
# Score 3 --> "avoid pink"
# Score 4 --> "avoid pink"
# Score 3 --> "great! "
# Score 5 --> "nan"
# Score 3 --> "good! "
# Score 4 --> "good!"
# Score 4 --> "nan"
# Score 5 --> "excellent!"
# Score 5 --> "nice work"
#
# Context: partial, Complexity: 1
# Cumulative Score: 7
# 5bcf6b423a99c40001542fa1:610c215bf664244fa0451390
# Score -2 --> "The positive objects were in the left hand corner, apart from the one right in the corner itself."
# Score 1 --> "The first object you got was negative, all the others in that top right corner were positive. "
# Score 0 --> "The objects in the bottom left hand corner were positive, apart from the one right in the corner "
# Score 2 --> "Good going, they were the right ones."
# Score 0 --> "All the objects in the top right hand corner were positive"
# Score 2 --> "Good job, the second object was negative but the others were positive"
# Score 2 --> "Good work, you managed to avoid the negative object in that corner"
# Score 1 --> "all the objects in that corner were positive apart from the second one you took"
# Score -1 --> "All the objects in the top left corner were positive."
# Score 2 --> "Top right was the best corner, but good work."
#
# Context: full, Complexity: 1
# Cumulative Score: 0
# 5c05c339b3ea3800017ae156:610ad4594e969ded4f0cf28b
# Score -3 --> "Rip"
# Score -1 --> "You’ll do better next time"
# Score 2 --> "The green was on the bottom left"
# Score -2 --> "It changed :("
# Score 4 --> "Yay"
# Score -4 --> "Poop"
# Score 1 --> "Ok"
# Score 0 --> "The pink were positive this round"
# Score -2 --> "Pink"
# Score 5 --> "Yes pink"
#
# Context: partial, Complexity: 1
# Cumulative Score: 3
# 5c0873675b32d500012e3f2c:610ac6d0fa849ef35d957598
# Score 0 --> "Head for bottom left Bottom left corner or bottom right corner "
# Score -2 --> "I'm so confused, sorry. Everything that is currently in the bottom right corner are good points if that helps. If they have a specific colour or shape then try and get them in the next round  I hope that makes sense"
# Score 1 --> "Nice one! We scored a point. Everything in the bottom left corner at the moment is a point apart from the one that is right in the corner. If they have a shape or colour associated with them then try and get those ones next round.  "
# Score -1 --> "They change each round so they should have shapes and colours associated with them. They change each time though. Right now there are points in the top right corner but that might not be the same next round. I would say next time head for bottom right corner but I can't say for sure.  Whichever shape is currently most in the top right corner of the screen then go for that in the next round. But go for the shape and colour that is currently there rather than heading for that specific corner. "
# Score 1 --> "Yay well done! At the moment all the minus points are in the bottom right and everything that is in the top right corner is positive. So whatever shape and colour is there at the moment, try and aim for that. "
# Score 0 --> "Awh unlucky. You were heading for a point though.  In the top right corner at the moment every one apart from the one nearest to the centre is a -1. The one nearest to the centre is a point. "
# Score 0 --> "Awh man unlucky again. They were points in the corner. Everything in the bottom left right now is a point apart from the one nearest the centre again which is a -1. Whatever shape and colour is most frequent in the bottom left corner right now, aim for that in the next round. "
# Score 1 --> "Well done! We were really close to 2 points then. 4/5 in the bottom right corner at the moment are points with a -1 at the bottom"
# Score 0 --> "Awh unlucky again. We keep getting so close. They were points again. Everything in the top left corner at the moment are points so head for whatever shape/colour is currently there."
# Score 3 --> "Amazing, well done!"
#
# Context: full, Complexity: 1
# Cumulative Score: 17
# 5c17c149f596b100011ca8b8:610c1b9abcbf26fce712faad
# Score -2 --> "The hollow shapes were good this time, both colors and shapes"
# Score 0 --> "You should avoid the filled in shapes"
# Score 0 --> "You can use two arrow keys at once to move diagonally. Remember to move towards hollow shapes"
# Score 0 --> "Remember to avoid the filled in shapes, you lost two points there for picking up filled in shapes"
# Score 2 --> "Good job. Keep doing that"
# Score 2 --> "Doing good!"
# Score 3 --> "Great job"
# Score 4 --> "Doing very good"
# Score 5 --> "Perfect"
# Score 3 --> "Great"
#
# Context: partial, Complexity: 1
# Cumulative Score: 5
# 5c4482688bb6fd000164149c:610bef2effe5a0eda25fabd5
# Score -1 --> "hard luck"
# Score 3 --> "nice job "
# Score 1 --> "sweet"
# Score 0 --> "tough luck"
# Score -4 --> "The oppisite spelling mistake sorry, its a tough game."
# Score 1 --> "be better if the ship moved faster."
# Score 2 --> "all green!!"
# Score 0 --> "All bottom right were green ."
# Score 0 --> "top left is where all the points are."
# Score 3 --> "nice one."
#
# Context: partial, Complexity: 4
# Cumulative Score: 17
# 5ca9f8926025570001c872f3:610c048b79afad201974a45d
# Score -3 --> "Nice try"
# Score 2 --> "You are doing great"
# Score 2 --> "nan"
# Score 2 --> "Doing great!"
# Score 2 --> "nan"
# Score 1 --> "nan"
# Score 3 --> "Great score!!!!"
# Score 2 --> "nan"
# Score 3 --> "One more level to go!!!"
# Score 3 --> "WOW!!!!"
#
# Context: partial, Complexity: 1
# Cumulative Score: 31
# 5cb5941ba7dfd50001759040:610bf7f5147addff9606bced
# Score -3 --> "everything you collected was negative. the top left had all positive, except the top second from the left item. the bottom left was all positive except what was in the far bottom left corner "
# Score 1 --> "okay this time everything in the bottom right corner was positive, so try going for shapes/colors that look like that. avoid the shapes/colors that were in the bottom left, those were all negative "
# Score 3 --> "good job! this time in the bottom left there was only one negative in the very left bottom corner. hope that helps! "
# Score 4 --> "it seems like you have the hang of this, but just to make sure, everything in the bottom left was negative and there is one negative below you right now "
# Score 5 --> "nice :) again everything in the bottom left was negative "
# Score 3 --> "you got it down "
# Score 4 --> "nice! "
# Score 4 --> "nice again "
# Score 5 --> "nice "
# Score 5 --> "awesome! thanks for the money "
#
# Context: full, Complexity: 4
# Cumulative Score: 22
# 5ce7c46d79642d0017767d94:610c1b9a3ebc4299d4805b61
# Score 1 --> "It's  not easy to do much in the time allowed.   We will do well next round. "
# Score 2 --> "2 points well done. "
# Score 2 --> "2 more points. keep going. "
# Score 3 --> "3 Points that round. "
# Score 2 --> "2 points. we are doing well "
# Score 2 --> "2 more points. We are winning. "
# Score 2 --> "" more points. "
# Score 2 --> "Seems to be 2 points every round. "
# Score 3 --> "3 that round"
# Score 3 --> "3 points. well done.  "
#
# Context: full, Complexity: 4
# Cumulative Score: 5
# 5d02c0e382e4f00001aa20cd:610c0bae7835ccc524c3f53d
# Score 0 --> "trying again"
# Score 1 --> "good"
# Score -1 --> "blue triangles"
# Score -3 --> "closed pink, open blue"
# Score 0 --> "catch closed pink triangle/square and open blue triangle/square"
# Score 2 --> "got it!"
# Score 0 --> "stay away from open pink triangle/squares and stay away from closed blue triangle/squares"
# Score 3 --> ":)"
# Score 5 --> "excellent!"
# Score -2 --> "not correct. follow previous instructions."
#
# Context: full, Complexity: 1
# Cumulative Score: 20
# 5d0e1827c26b9e00016b9f94:610c048a801f1c540397a152
# Score 2 --> "good"
# Score 0 --> "empty triangle is positive 1"
# Score 0 --> "good"
# Score 2 --> "k"
# Score 3 --> "good"
# Score 2 --> "l"
# Score 3 --> "l"
# Score 2 --> "l"
# Score 3 --> "ll"
# Score 3 --> "good"
#
# Context: partial, Complexity: 4
# Cumulative Score: -14
# 5d5f07cdca10e90016bc0103:610bf38ae979f2df8455c05c
# Score -2 --> "Not so good that corner, only one positive there"
# Score 0 --> "not too bad, but bottom right corner would be better, bottom left corner rubbish"
# Score 1 --> "not too bad, bottom left corner was the best one to go for. "
# Score -3 --> "that corner they were all negative unfortunately. top right was better this round"
# Score 1 --> "average that corner, bottom left was all negative, top right was all positive"
# Score -1 --> "more negative that positive there, bottom two corners both has 3 positvie and 2 negative"
# Score -2 --> "you got no positive then. bottom left was the best"
# Score -2 --> "only one positive there, bottom right had 4 positives."
# Score -3 --> "top left was all positive, that corner not so much. oh well! XD"
# Score -3 --> "Never mind eh? at least we have our base pay!! XD"
#
# Context: full, Complexity: 4
# Cumulative Score: 26
# 5d6ef95300c9130018c7e64c:610ad45836d28ba4e03f0e31
# Score 3 --> "get the light blue solids and the hollow pinks"
# Score 3 --> "Get the solid blues and the hollow pinks!"
# Score 2 --> "get the light blue solids and the hollow pinks "
# Score 3 --> "good job! now get the light blue solid and hollow pinks "
# Score 3 --> " now get the light blue solid and hollow pinks "
# Score 1 --> " now get the light blue solid and hollow pinks "
# Score 2 --> "get the light blue solid and hollow pinks. keep going! "
# Score 3 --> "go for the light blue solid and hollow pink "
# Score 3 --> "go for the hollow pinks and solid blue "
# Score 3 --> "good job! get the solid blue and hollow pink "
#
# Context: partial, Complexity: 1
# Cumulative Score: -1
# 5d8cef3c28e183001a335ab0:610ad45a8d158e1bfb034b8d
# Score 2 --> "Cool! "
# Score 2 --> "nan"
# Score 0 --> "nan"
# Score -4 --> "nan"
# Score -1 --> "Almost! "
# Score 0 --> "Almost!"
# Score 2 --> "Yay!"
# Score 2 --> "Yay!"
# Score -2 --> "Aww"
# Score -2 --> "Good try!"
#
# Context: full, Complexity: 4
# Cumulative Score: 18
# 5dcd750828792003fc23dc39:610bf7f5b66b62177c350013
# Score -1 --> "Choose the solid squares and empty triangles"
# Score 4 --> "Great job!"
# Score 2 --> "Choose the solid squares and empty triangles"
# Score 1 --> "Great job!"
# Score 1 --> "Choose solid squares and empty triangles. Try and chose one corner at a time."
# Score 2 --> "Choose the most solid squares and empty triangles in one corner."
# Score 2 --> "Because of the limited time, choose one corner. Then move over the solid squares and triangle outlines."
# Score 2 --> "Because of the limited time, choose one corner to get the most points. Then move over the solid squares and triangle outlines only."
# Score 4 --> "Because of the limited time, choose one corner to get the most points. Then move over the solid squares and triangle outlines only."
# Score 1 --> "Because of the limited time, choose one corner to get the most points. Then move over the solid squares and triangle outlines only."
#
# Context: full, Complexity: 1
# Cumulative Score: 25
# 5e121701dc79bd8a1a22ca99:610c16ca85279a60b5a9e930
# Score 2 --> "The squares are positive"
# Score 3 --> "nan"
# Score 3 --> "Good"
# Score 3 --> "nan"
# Score 2 --> "You can move diagonally, that might be quicker"
# Score 1 --> "nan"
# Score 2 --> "Good"
# Score 3 --> "nan"
# Score 3 --> "Good"
# Score 3 --> "nan"
#
# Context: partial, Complexity: 4
# Cumulative Score: 19
# 5e28456cb66c4d016fd05e57:610bf7f443952ccd05b08c9a
# Score -3 --> "only the middle point in that corner was positive the bottom left corner is all positive except for the point right in the corner same with the top left but the negative point on the right"
# Score 3 --> "nice. You skipped the negative point and went for all positive points in that corner. :) bottom right corner was all positive points bottom left corner is all negative points"
# Score 2 --> "that point in the far corner of top left was positive, you could have got it bottom left is positive except for the point closest to the corner top right the 2 points in the middle are positive"
# Score -1 --> "top left the furthest points are positive bottom left is all negative top right is positive except for the point closest toward the middle starting spot"
# Score 4 --> "nice. all top right is positive all bottom left is negative bottom right the 2 points furthest from your current location are positive"
# Score 1 --> "the seond point you took was negative top left  the 2 middle points are positive bottom right the 2 points closest to the centre staring spot of positive top right is negative except for the point closest to centre starting spot"
# Score 2 --> "the middle point remaining in the top left is positive bottom left is positive except for the the point closest to centre start spot bottom right the 2 points in the middle are positive"
# Score 2 --> "bottom right is positive except for the point furthest down top right is all negative top left is negative except for the point closest to you now bottom left remains all negative"
# Score 4 --> "nice, top left was all positive :) bottom left negative except for the middle point bottom right negative except for the point that is top right for that configuration"
# Score 5 --> "awesome. bottom right is all negative top left is positive except for the point closest to center start spot bottom left negative except for the point furthest down"
#
# Context: partial, Complexity: 4
# Cumulative Score: -5
# 5e3de55071cf2606b45c50a6:610c132f6d79e1ded8767991
# Score -3 --> "bottom left, all except corner"
# Score 1 --> "Score 0 if you're a person"
# Score 2 --> "."
# Score -3 --> "."
# Score -4 --> "top right"
# Score 1 --> "."
# Score 3 --> "/"
# Score -1 --> "/"
# Score -3 --> "beep boop"
# Score 2 --> "p"
#
# Context: partial, Complexity: 4
# Cumulative Score: 27
# 5e5d641259df370779040d9e:610c25813eafdc3ec226d57e
# Score -1 --> "Those were both negative "
# Score 2 --> "top right  bottom right is all positive "
# Score -1 --> "far left hurry! "
# Score 4 --> "Top right "
# Score 5 --> "great job! "
# Score 0 --> "great job!  "
# Score 4 --> "stay there "
# Score 4 --> "down "
# Score 5 --> "stay in the middle on the far right "
# Score 5 --> "well done! all positive "
#
# Context: full, Complexity: 4
# Cumulative Score: 23
# 5e740451f1e6520f51f3eece:610c0f404194a2ab58f9a62e
# Score -3 --> "blue shapes that arent filled in are good and pink shapes that are filled in are also good "
# Score 5 --> "yep just like that "
# Score 4 --> "yess :) "
# Score 2 --> "doing good! "
# Score -5 --> "ok remember the blue shapes that arent filled in are good and the pink shapes that are filled in are also good. so try for those "
# Score 3 --> "that was good!! "
# Score 3 --> "👍 "
# Score 4 --> "you're awesome "
# Score 5 --> "going to that corner was the best choice! "
# Score 5 --> "you have really good reflexes! good job! i think that was our last round "
#
# Context: partial, Complexity: 1
# Cumulative Score: 28
# 5e8e11676c1dea0be7a64cb3:610bfd2297422a184d69b7ee
# Score 0 --> "boxes with 1 are the positive ones"
# Score 3 --> "great"
# Score 1 --> "average"
# Score -2 --> "top r"
# Score 5 --> "top right"
# Score 3 --> "nice"
# Score 4 --> "niceee"
# Score 4 --> "great"
# Score 5 --> "beautiful"
# Score 5 --> "niceeee"
#
# Context: full, Complexity: 4
# Cumulative Score: 3
# 5e95e7a1e8791a04edea8690:610c215b0911bcaaee5af890
# Score -1 --> "Aim for the blue triangles and the pink squares "
# Score -1 --> "The pink triangles will make you loose points  "
# Score 0 --> "nan"
# Score 0 --> "??"
# Score -1 --> "NO BLUE SQUARES OR PINK TRIANGLES   NO BLUE SQUARES OR PINK TRIANGLES, THEY MAKE US LOOSE POINTS "
# Score 1 --> "Yes go for the pink square but NOTHING else in that corner  "
# Score 1 --> "Yay"
# Score 2 --> "Good job"
# Score 1 --> "!!"
# Score 1 --> "!!"
#
# Context: partial, Complexity: 4
# Cumulative Score: 5
# 5ea019431fa8990256915ea7:610c16d3a8abde4b1bead402
# Score -1 --> "Okay for this one the top riight is a negative as is two to the left and down, bottom left is also a negative, top left second one is a negative and bottom right the only positive is the one that is left."
# Score 4 --> "Well done all the bottom right were positive. All the top right 4 are positive, all the bottom right are negative and top left is negative as is the 3rd one down."
# Score 3 --> "Well done you got all the positives. Bottom left is a negative. The top left top three are positives, the top right first two are negatives, then below are 2 positives , then below this a negative. At the right hand side bottom right is a postiveas is two up and 2 left"
# Score 0 --> "bad luck. Top right top two are positives, next line is a negative and two positives. Top left is a positives with positive directly below and to the right, other two are negative. Bottom left is all negative. Bottom right the corner is a positive,as is the one diagonally to the left, rest are negative. "
# Score 3 --> "Well done. All top right are positive. All bottom left are negative. Top left top two are negative, next line is positive, next line is a positive and negative. Bottom right is positive in right hand corner. To the left is positive as is two up. The rest are negative "
# Score -3 --> "bad luck, top right two are negative the two outside of this are positive and the outer one negative. Top right  next to spaceship left is negative below is postive. Bottom left corner is negative above two are positive  and right is positive further away is negative. Bottom right is positive the line to the left is negative and the next line to left is positive. "
# Score 1 --> "well done. you got positive. to the right is negative. two below are negative and below is positive"
# Score 0 --> "all top right is negative. All bottom right is positive apart from the corner one which is negative. bottom left line is negative. line above is positive. top left line is all negative. line below is positive then negative. "
# Score -2 --> "bad luck. all top left is positive, all bottom left is negative apart from th eone in the middle. top right is negative the line below is positive then the line below is positive wth negative next to it. bottom right is negative. "
# Score 0 --> "bad luck all top left and top right is positive. all bottom right is negative. all bottom left line is negative, positive, then negative. the line above this is all negative."
#
# Context: partial, Complexity: 4
# Cumulative Score: -2
# 5ea45eb9abef8a07bcced2bc:610c0bb45333701704e5c71c
# Score 1 --> "bottom left - initial ones are all positive"
# Score 0 --> "Bottom right are all positive"
# Score -1 --> "bottom left are positive"
# Score -3 --> "top right but not the first one"
# Score -1 --> "top right are positive"
# Score -2 --> "bottom left over the two over by the side"
# Score -1 --> "bottom left but not the first one"
# Score -2 --> "bottom right are positive"
# Score 3 --> "top left are positive"
# Score 4 --> "top right are positive"
#
# Context: full, Complexity: 4
# Cumulative Score: 20
# 5eb77fcb7516866b1aa8332f:610ad456a806d3a4819ff354
# Score 1 --> "Scoring was random. Not related to shapes or colours"
# Score 4 --> "Good job, you definitely chose the correct corner"
# Score 0 --> "Not bad. Again, points and colours don't have a correlation?!"
# Score 1 --> "Empty triangles were the ones to go for"
# Score 1 --> "Empty/hollow blue triangles and squares are the ones to go for"
# Score 2 --> "Good job! You can all pink filled triangles to the list, so blue + empty[triangles, squares] and pink + filled [triangles]"
# Score 2 --> "Good! that was a good corner to go for, you could have also gone for the empty square"
# Score -1 --> "ok, I think I've got a better idea, so go for any blue shape that is empty and any pink shape that's filled. bottom right in this round would have been the way to go"
# Score 5 --> "excellent! any blue shape that's empty and any pink shape that's filled"
# Score 5 --> "Nice! chose well again!"
#
# Context: partial, Complexity: 4
# Cumulative Score: 3
# 5ec2feeb47c4471339d3b2ce:610c25847333ff0c04ab1e49
# Score -1 --> "collect all in the top left and all in the bottom left"
# Score 1 --> "collect all in the bottom right and then all in top right "
# Score -1 --> "collect all in bottom left "
# Score 0 --> "collect all in the top right"
# Score 3 --> "collect all top right  just collect all of them no matter where you go"
# Score 1 --> "collect all "
# Score 0 --> "collect all"
# Score -2 --> " unlucky"
# Score 1 --> "nice!  "
# Score 1 --> "go gog og"
#
# Context: full, Complexity: 4
# Cumulative Score: 8
# 5ee3a34e16ad19048aef74f6:610c132c6ae96525ef7c0183
# Score -2 --> "pink triangle and blue square good  "
# Score 4 --> "pink triangle blue square "
# Score 2 --> "woo"
# Score 3 --> "pin triangle"
# Score 2 --> " ok"
# Score -1 --> "ok "
# Score 1 --> "great"
# Score -2 --> "too bad"
# Score -2 --> "ok"
# Score 3 --> "good"
#
# Context: partial, Complexity: 1
# Cumulative Score: 43
# 5efa7432ebc08a170f0aa15f:610bfd1eb370cd08a2eeafd5
# Score 4 --> "really good choice you got all +points no- "
# Score 5 --> "Amazing you picked the best corner again"
# Score 4 --> "Well done for Avoiding them - "
# Score 4 --> "great job"
# Score 5 --> "Fab 5 Point again"
# Score 3 --> "well done Best you could of got"
# Score 4 --> "wwe well done another 4 in the bag"
# Score 4 --> "best choice well done "
# Score 5 --> "You doing great well done "
# Score 5 --> "well done you did fab"
#
# Context: full, Complexity: 1
# Cumulative Score: 38
# 5efea1f363271c3b76d4c9ed:610c132b92410290c346435f
# Score 1 --> "positive triangles and squares (pink)"
# Score 3 --> "all pink are positive"
# Score 4 --> "great job!! all pink are still positive (will let you know if that changes)"
# Score 4 --> "doing great! no changes!"
# Score 5 --> "Awesome!! Keep going after the pink!"
# Score 3 --> "doing great!!"
# Score 4 --> "great job going after the biggest group!"
# Score 4 --> "great!!"
# Score 5 --> "Great Job! Still no changes! only 1 level left"
# Score 5 --> "Great Job!  Thanks for being an awesome partner"
#
# Context: full, Complexity: 1
# Cumulative Score: 36
# 5f0f59f3bc44f50f92845a05:610ac6cb72e1fd3df6607949
# Score -3 --> "only purple "
# Score 5 --> "same again keep going :)"
# Score 4 --> "well done :) still only purple try and get as many as you can"
# Score 4 --> "well done keep going as many as you can ]"
# Score 5 --> ":)"
# Score 3 --> "better luck next time"
# Score 4 --> "keep trying"
# Score 4 --> "well done"
# Score 5 --> ":)"
# Score 5 --> "well done :)"
#
# Context: partial, Complexity: 1
# Cumulative Score: 10
# 5f1bf7bb9f48184274051108:610bef33f74b089ec4314b4b
# Score 1 --> "Only the one on the corner was -1"
# Score 2 --> "Only the first one you took was -1"
# Score 3 --> "The one in the corner was -1"
# Score 0 --> "The -1 were the ones on the side"
# Score 5 --> "All the ones on the bottom left were -1"
# Score -1 --> "The first one you took and the two on the top were -1"
# Score -1 --> "The bottom left corner were all +1 except for the one furthest top"
# Score 2 --> "All the ones on the bottom right corner were +1s except the one that were the lowest"
# Score -4 --> "All the ones on the top left corner were +1"
# Score 3 --> "All the one on the top right corner were +1"
#
# Context: full, Complexity: 4
# Cumulative Score: 39
# 5f3519c52c61cf45f186a7b9:610c0f3c44f2013a9e42f342
# Score 2 --> "Pink solid triangle and hollow +, solid blue square and hollow +"
# Score 4 --> "Great! Solid and hollow pink triangle +, solid and hollow blue square + "
# Score 3 --> "Same again I think: solid and hollow pink triangle, solid and hollow  blue square "
# Score 4 --> "Perfect! Same pattern continues I think."
# Score 5 --> "spot on! Same again..."
# Score 3 --> "Nailed it. Same again but quick reminder: solid and hollow pink triangles are +, solid and hollow blue squares +"
# Score 4 --> "Perfect. I'll let you know if the pattern changes. No change yet."
# Score 4 --> "Perfect again. Keep going..!"
# Score 5 --> "Bonus looking pretty tasty! Just one more; same again, please!"
# Score 5 --> "Nice job! Totally nailed it! Thank you, friend!"
#
# Context: full, Complexity: 4
# Cumulative Score: 37
# 5f4505a4ad6fa004d3a226f3:610c048b7d501b7777f9ceaf
# Score 3 --> "Good job! "
# Score 0 --> "Go for filled pink shapes and hollow blue shapes only."
# Score 4 --> "Well done.  That was all positive!  Same rules again. "
# Score 4 --> "You went for the best corner and did the best possible!  Well done! "
# Score 5 --> "Well done again.  Perfect performance.  Again: filled pink and hollow blue are good. "
# Score 3 --> "Well done.  There wasn't much available but you did perfectly. "
# Score 4 --> "Well done.  That was great.  Keep up the good work. "
# Score 4 --> "Great work again.  You are super quick at locating the best area. "
# Score 5 --> "Brilliant job.  One more round to go. "
# Score 5 --> "Well done!  You have been amazing!  Thanks for being brilliant. "
#
# Context: partial, Complexity: 1
# Cumulative Score: 14
# 5f4fcf616d9ce70ea9684e10:610c295e4ec14b898f2ce74a
# Score 1 --> "go fot the first one you picked the 2nd is negative"
# Score 1 --> "what the bottom right was was all positive scores"
# Score 0 --> "your first 2 objects were negative scores"
# Score 2 --> "all positive their well done"
# Score 2 --> "all the object in the area you were in were positive scoring"
# Score 2 --> "both of those were poitive the object on the left of you is also positive"
# Score 2 --> "both positive again but the objects on your bottom left apart from the one closest too you are all positive too."
# Score 1 --> "the bottom right would have been a better way to go all objects and colours their are positive  apart from the one closest to the bottom of the screen"
# Score 0 --> "1 positive 1 negative all the shapes and colours in the top left were positive"
# Score 3 --> "the first object you picked was negative the rest positive"
#
# Context: partial, Complexity: 4
# Cumulative Score: 10
# 5f504fd2cc049d1cbf29c40d:610c132feb658c48e4b018cd
# Score 2 --> "The first two blocks were good! There was one -1 to the top right of that cluster."
# Score 0 --> "Everything in the bottom right corner was good."
# Score 2 --> "almost perfect, the last shape was a -1"
# Score 2 --> "First shape was a -1, but it looked like maybe you weren't meaning to touch it."
# Score 1 --> "Everything in the top right was a positive 1 That corner was a mix of stuff. that you went to i mean"
# Score 1 --> "That first shape was a -1"
# Score 3 --> "That was perfect the shape to your immediate left is also a positive the one above you to the right is -1"
# Score -3 --> "those were all -1"
# Score -2 --> "Everything in the top left corner is a positive Most of the shapes you got there were negative"
# Score 4 --> "hell yeah. perfect."
#
# Context: full, Complexity: 1
# Cumulative Score: 38
# 5f512c4654658b32090cbd6a:610bf3885e2d512220e7b5bb
# Score 3 --> "Awesome! Squares give you a reward! Nice intuition! "
# Score 4 --> "Perfect! The student becomes the teacher!  "
# Score 4 --> "Great work! As long as you avoid triangles, you're golden! "
# Score 4 --> "Perfect! That was a great cluster to aim for! It gave you the most possible points in such a short time "
# Score 5 --> "Couldn't have done it better myself!  "
# Score 3 --> "This board was trickier than normal and you made a great choice! "
# Score 2 --> "That was a tricky one! No worries, one mistake is no big deal!  "
# Score 3 --> "Great! You have such a short amount of time, you are doing great getting as many squares as possible! "
# Score 5 --> "Perfect job! "
# Score 5 --> "Awesome! You've got the hang of this! "
#
# Context: full, Complexity: 1
# Cumulative Score: 36
# 5f56c84476632c13430bf939:610c258409b41400b6ebfd18
# Score -2 --> "In this round all the outline sapes are negative and all the solid shapes are positive "
# Score 4 --> "Excellent - you went for the solid shapes. Try this again for the next round "
# Score 4 --> "Great choice of corner - mostly solid shapes. Again, this was the right choice "
# Score 4 --> "Excellent choice again - avoided the corner with all outlines and went for the solid shapes.  "
# Score 5 --> "Well done - good choice of corner again! "
# Score 3 --> "Your strategy remains very good. There was no obvious corner to head for but you made the best choice "
# Score 4 --> "Excellent strategy again - the alien just moves too slowly to reach the second corner "
# Score 4 --> "Best choice of a difficult screen. Very good strategy again "
# Score 5 --> "An easier screen which you made the most of - well done! "
# Score 5 --> "I think this was the last screen - excellent work. "
#
# Context: full, Complexity: 1
# Cumulative Score: 34
# 5f74b3a0d780450b219f8616:610ac6ccdf3fe50fa0f75fc5
# Score -2 --> "Try for a different shape or a different color on the next round - the pink square is negative"
# Score 2 --> "Nice! Go for triangles :)"
# Score 4 --> "Awesome"
# Score 4 --> "Keep it up!"
# Score 5 --> "Perfect 👍 "
# Score 3 --> "Great job"
# Score 4 --> "That corner was a good choice!"
# Score 4 --> "Nice! Just a couple more levels "
# Score 5 --> "Sweet! "
# Score 5 --> "Awesome job!"
#
# Context: full, Complexity: 4
# Cumulative Score: 6
# 5f7760d025023628ce3f4d05:610c2585a34e9917a08a8f36
# Score -2 --> "teal blank squares and teal triangles are good, as well as purple triangles and blank squares "
# Score 3 --> "good job, in this one the blank triangles bad and filled and blank  in teal squares good "
# Score 1 --> "good job, in this one it was blank and filled in purple triangles and filled in teal squares id say go for either filled in or go for blank, but not both. You got this!!"
# Score 0 --> "nice try nice try, this one was teal and purple blank squares good and filled in teal and purple squares good "
# Score -4 --> "good try!! this one was the same as last time "
# Score -3 --> "also good try, but it hasnt changed from the last 3 roundds. you got this!!"
# Score 3 --> "good job!!!!"
# Score 2 --> "good job! the good ones still havent changed, i wish the timer was longer so you could get more!! youre doing great"
# Score 3 --> "good job"
# Score 3 --> "great job!! good game!!"
#
# Context: full, Complexity: 1
# Cumulative Score: 33
# 5f784d0ac0c40e3ca59f3d71:610bef30ccc9a7bbfdb13968
# Score 0 --> "I didn't realise the shapes would change etc, sorry. For this round, the triangles were all good and the squares were all bad. The ones on the left tend to be easier to gain points."
# Score 2 --> "Triangles were all good"
# Score 4 --> "Keep going for the triangles :) "
# Score 4 --> "nan"
# Score 5 --> "nan"
# Score 2 --> "nan"
# Score 3 --> "good job "
# Score 4 --> "nan"
# Score 4 --> "Good job :) keep going for the triangles that look the easiest to get to to ensure you get as many as possible"
# Score 5 --> ":)"
#
# Context: full, Complexity: 4
# Cumulative Score: 25
# 5f85c88c61e23608718cbd03:610bf7f2802c05117e349a22
# Score 3 --> "Doing great bottom left looks good "
# Score -3 --> "Filled blue are points "
# Score 0 --> "filled blue and hollow pinks are points for us"
# Score 4 --> "great youve got it"
# Score 5 --> "well done yes filled blue and hollow pink are points for us"
# Score 3 --> "keep going"
# Score 3 --> "great keep going"
# Score 3 --> "filled blue both triangles and squares are points for us"
# Score 3 --> "top left would have been 5 points there"
# Score 4 --> "great"
#
# Context: full, Complexity: 4
# Cumulative Score: 20
# 5f969b802a498b000aab2571:610c0bb43ba7eb1f6b841209
# Score 1 --> "empty triangles and full squares are bad!"
# Score 3 --> "Nice one!! :D "
# Score 2 --> "Empty triangles and full squares we avoid, you got this! "
# Score 0 --> "I am hoping that these messages are helping but your task is way harder than mine!! "
# Score -2 --> "Full squares (squares that have the insides coloured in) and triangles that don't have the insides coloured in are always negative points!"
# Score 2 --> "Woooo, keep aiming for full triangles and empty squares! "
# Score 3 --> "wahooo, empty squares and full triangles are the best! "
# Score 3 --> "empty squares and full triangles <3 <3 "
# Score 4 --> "empty squares and full triangles, SMASHING IT! "
# Score 4 --> "empty squares and full triangles, so proud!  "
#
# Context: full, Complexity: 4
# Cumulative Score: 13
# 5f9b2a48d673c431efe4b94b:610c0487712b02c7aa28516d
# Score -3 --> "green squares in top left hand corner and on the right side corner"
# Score 1 --> "the one you were going to hit is positive "
# Score 1 --> "there is four in the bottom hand corner which is positive"
# Score -2 --> "you need to go to the top right hand corner there is four positive shapes there "
# Score 4 --> "great the next best one was the bottom right hand corner"
# Score 0 --> "best one would have been bottom right hand corner"
# Score -1 --> "filled in triangles are negative and empty squares are negative"
# Score 4 --> "okay so filled in coloured boxes are positive"
# Score 4 --> "fantastic also empty triangles are positive"
# Score 5 --> "brilliant"
#
# Context: partial, Complexity: 4
# Cumulative Score: 14
# 5f9b3b52d60a821cf75f52de:610c1b9e3fa3b8c008a75f39
# Score -2 --> "That was a nice try! "
# Score 4 --> "Dang way to go that was nice! "
# Score 2 --> "good job! "
# Score 2 --> "way to go! "
# Score 0 --> " "
# Score -4 --> "that was a nice try! "
# Score 3 --> "great job!  "
# Score 2 --> "great job!  "
# Score 3 --> "Wow you're a pro "
# Score 4 --> "that was awesome! "
#
# Context: partial, Complexity: 4
# Cumulative Score: 20
# 5fa4f94e535f3b1aa628e0ab:610ac6cf4d8fc0767cfcddbe
# Score 0 --> "You didn't score any points that time, those shapes were a positive and negative "
# Score 3 --> "That was good, you picked all positive shapes "
# Score 1 --> "The first two shapes you picked were positive, the third was negative  "
# Score 3 --> "Great! all positive, keep it up :-) "
# Score 2 --> "Great! Three out of four were positive.  All the shapes in the top right would have been positive "
# Score 1 --> "We scored 1 point there! "
# Score 3 --> "Well done, all three were positive scores "
# Score 2 --> "Great! 2 positive points "
# Score 1 --> "Great! if you'd gone top left you could have got more points in one go though! "
# Score 4 --> "Fab! 4 points "
#
# Context: partial, Complexity: 1
# Cumulative Score: 11
# 5fd0ed3ee993330172b0b97a:610ad4590b4e00b9590ab025
# Score 0 --> "The one to your left that you almost hit was negative, the rest in that corner were positive"
# Score -1 --> "The one you hit was negative but th erest in that corner were positive. I think the colours/shapes for the positive/negative stay the same?"
# Score 1 --> "Yes perfect, obviously the one in the far bottom left corner was the only negative one in that cluster"
# Score -1 --> "They were all negative in that corner"
# Score 0 --> "unlucky! they were all positive in that corner."
# Score 2 --> "Yes perfect! The other positive one in that cluster was the one right in the corner"
# Score 2 --> "I think you've mastered it!"
# Score 3 --> "Perfect...you don't even need me!"
# Score 3 --> "Nice work, its a shame it can't move faster :)"
# Score 2 --> "Great job!"
#
# Context: full, Complexity: 1
# Cumulative Score: 42
# 5fd7782dee03dc08d3f3f491:610bfd229e05c75c72de8a77
# Score 3 --> "Squares were +1, Triangles -1"
# Score 5 --> "perfect! no changes in types. still looks to be squares are the go to"
# Score 4 --> "great! same thing again!"
# Score 4 --> "I apparently got teh easy job, only had to say one thing lol. Same thing, no changes this round."
# Score 5 --> "perfect again."
# Score 3 --> "you got this! no issues"
# Score 4 --> "doing great, i feel a little useless in this one haha. but thanks for doing the work."
# Score 4 --> "!!"
# Score 5 --> "again, perfect"
# Score 5 --> "awesome and great job!"
#
# Context: full, Complexity: 4
# Cumulative Score: 11
# 5fe5e424a53c573e8eed248d:610bf7f3a929110b4ad7c19c
# Score -1 --> "Get pink triangles and squares (filled) "
# Score 1 --> "Get emty blu squares and triangles and filled pink squres and triangles"
# Score -2 --> "+1 Blue square and triangle outlines and filled pink squares and triangles -1 Blue filled squares and triangles and pink square and triangle outlines "
# Score 1 --> "Avoid the filled blue squares The top right corner will give you the most points"
# Score 4 --> "You could've gotten the other triangle in the top right"
# Score -2 --> "Avoid the pink triangle out line, the position of things has changed Always go for the filled pink shapes and the blue outlines"
# Score 3 --> "Filled pink shapes and blue outlines"
# Score 4 --> "Good!, Filled pink shapes and blue outlines"
# Score -1 --> "No, Filled pink shapes and blue outlines will get you points"
# Score 4 --> "Good!"
#
# Context: partial, Complexity: 4
# Cumulative Score: 10
# 5ff85878c73c7102572ca342:610bef310648e301cdb3ad25
# Score -2 --> "okay my bad, that was for the previous one. Both of those shapes that you picked are negative.  out of the five in the top left corner, four of them were positive. Same thing with the ones in the bottom left corner.  In the bottom left, the shape in the furthest corner is negative. The other four shapes around it are positive.  So those shapes are positive, if that makes sense. They won't be in the same place but the colour/shape is positive."
# Score 1 --> "So this time, all the shapes in the bottom right corner were positive. And all the shapes in the bottom left corner were negative."
# Score 0 --> "I can't see what you're seeing, but I think if you just find the pattern in the shapes and colours that I tell you are positive you should be able to avoid getting negatives. For this level, if you went to the bottom left corner, you would have got 4 positives and 1 negative. The negative here is the shape in the bottom left most position, everything else around it is positive. "
# Score 3 --> "perfect! Yes! so the piece immediately to your left there was also positive. The piece next to that is negative. Good call. "
# Score 1 --> "Good call, all those pieces in the top right corner are positive."
# Score 0 --> "Unlucky, that was a mixed bag. The piece left there in that corner is also negative. "
# Score 2 --> "Great job. Those other two pieces left were both positive. The one that you avoided in that corner (slightly above where you are now) was negative."
# Score 2 --> "Another good round. Bottom right corner would have been better as the four shapes on the outer edge are all positive, with the piece on the inside of that arc of shapes being negative."
# Score 4 --> "Great round! All those shapes were positive. The one left over in that corner was also positive."
# Score -1 --> "Ah, unlucky. The top right corner would have been the perfect choice. All those shapes in the corner are all positive. "
#
# Context: full, Complexity: 1
# Cumulative Score: 38
# 5ffb8c5b60571908f3ac19fa:610bf38b750f6f1a30b12362
# Score 4 --> "Nice :) "
# Score 2 --> "Empty shapes are negatives - well done"
# Score 4 --> "Good work"
# Score 4 --> "Good job avoiding the negatives"
# Score 5 --> "Woohoo, well done"
# Score 2 --> "Good try"
# Score 4 --> "Good job"
# Score 3 --> "Try again to avoid the negatives"
# Score 5 --> "Great job, one to go"
# Score 5 --> "Smashed it, well done "
#
# Context: full, Complexity: 1
# Cumulative Score: 33
# 6008057b6fbeef0d476b756b:610c0f3cfc85d50b5f838216
# Score -3 --> "The bottom left corner is a good option"
# Score 3 --> "Great work "
# Score 4 --> "Well done"
# Score 3 --> "Mostly right"
# Score 5 --> "Excellent work"
# Score 3 --> "Perfect!"
# Score 4 --> "Excellent!"
# Score 4 --> "Perfect again!"
# Score 5 --> "Perfect again!"
# Score 5 --> "Perfect, well done!"
#
# Context: full, Complexity: 1
# Cumulative Score: 36
# 601bef4596efd9620b3891dc:610c0bb371f74c662fa13e2f
# Score -3 --> "blue is negative "
# Score 5 --> "good job"
# Score 4 --> "nice one"
# Score 4 --> "good job"
# Score 5 --> "awesome job"
# Score 3 --> "good job"
# Score 4 --> "nice moves"
# Score 4 --> "winning!"
# Score 5 --> "awesome"
# Score 5 --> "good job"
#
# Context: full, Complexity: 1
# Cumulative Score: 36
# 604fa685e33606f9a0ee8189:610c295cfdb262b90502d5ed
# Score 1 --> "another point, points were in the not solid shapes, solid shapes were negative"
# Score 3 --> "well done"
# Score 3 --> "yes, you headed for the corner with the most points"
# Score 4 --> "brilliant"
# Score 4 --> "another good round"
# Score 3 --> "well done"
# Score 4 --> "brilliant, keep going"
# Score 4 --> "Great, wish it could move faster haha"
# Score 5 --> "Well done - last one coming up"
# Score 5 --> "you did great :)"
#
# Context: partial, Complexity: 4
# Cumulative Score: 21
# ...
# Score 5 --> "Thanks for all the help. :) "
#
# Context: full, Complexity: 1
# Cumulative Score: 40
# 60ff0bb5f091c10ddd2270b9:610c215c24ee1324b4b32e2b
# Score 2 --> "The solid ones were points and the hollow ones were negative "
# Score 5 --> "Awesome! The rules stayed the same for this one solid=points hollow=negative "
# Score 4 --> "Great job! "
# Score 4 --> "Awesome! "
# Score 5 --> "Great job! "
# Score 3 --> "Doing great! "
# Score 4 --> "Awesome!"
# Score 3 --> "You were so close to another point in the lower right hand corner, but you're still doing a fantastic job!"
# Score 5 --> "Perfect!"
# Score 5 --> "Fantastic!"
#
# Context: partial, Complexity: 4
# Cumulative Score: 8
# 60ff1e23b678cfde3cb24dbe:610c132f5f79194fd48faa6f
# Score 3 --> "The first 3 were points, the last was -1. "
# Score 3 --> "The last 4 shapes were points"
# Score 1 --> "First two were -1"
# Score 3 --> "First was -1 "
# Score 1 --> "First was -1... did they look different to you? "
# Score -1 --> "Second 2 were +1 "
# Score -1 --> "Middle 3 were -1 "
# Score -1 --> "... the shapes values stay the same throughout"
# Score -1 --> "Bottom two were -1, middle was +1 "
# Score 1 --> "First was -1  "
#
# Context: full, Complexity: 4
# Cumulative Score: 24
# 60ff2ad304d974fcb00058df:610c0bb41b02c369049a1cb6
# Score 2 --> "nice"
# Score -3 --> "no blue squares or purple triangles"
# Score 2 --> "great"
# Score 3 --> "great"
# Score 3 --> "great"
# Score 2 --> "nearly 3 , unlucky "
# Score 3 --> "great !"
# Score 4 --> "nice !"
# Score 3 --> "top left was better but nicely done "
# Score 5 --> "Excellent !"
#
# Context: full, Complexity: 4
# Cumulative Score: 25
# 60ff42b20bee1078e198b4e5:610bef33ecae4e68211bef9b
# Score -1 --> "Empty squares and full triangles are worth points :)"
# Score 3 --> "Brilliant yes!"
# Score 3 --> "Yep keep going for empty squares and full triangles"
# Score 3 --> "Yess brilliant!"
# Score 4 --> "Fantastic strategy :)"
# Score 2 --> "Great :D"
# Score 1 --> "Yes perfect place to head towards!"
# Score 4 --> "Perfect again!"
# Score 3 --> "Yes, full triangles and empty squares :)"
# Score 3 --> "Fab! :D"
#
# Context: partial, Complexity: 4
# Cumulative Score: 8
# 6100166b3f60cf7a8d837251:610ad45b75a150a370e3bcf9
# Score -2 --> "THE FIRST ONE YOU GOT WAS A BONUS"
# Score 3 --> "GOOD JOB!"
# Score 0 --> "THE LAST ONE AND THE FIRST ONE WERE BONUSES"
# Score 1 --> "ALL OF THEM BUT THE LAST ONE WERE BONUSES!"
# Score -4 --> "ALL NEGATIVES"
# Score -1 --> "OOPS WE'LL GET EM NEXT TIME!"
# Score 3 --> "GOOD JOB!"
# Score 2 --> "BOTH BONUSES!"
# Score 3 --> "ALL BONUSES GOOD JOB"
# Score 3 --> "GOOD JOB!"
#
# Context: partial, Complexity: 1
# Cumulative Score: 28
# 6100166b8b7de7dbe1ce05dd:610bf38abcc88351ccbdade8
# Score -3 --> "on bottom left corner, the one closest to corner is negative. top left corner, the top right one is negative. top right corner, the one closest to corner and the one on the far left side are negative"
# Score 2 --> "bottom right corner are all positive. bottom left corner are all negative. top right corner, the one on the bottom left is negative"
# Score -1 --> "bottom left corner, the one closest to the corner is negative. top left corner, the 2 bottom ones are negative. top right corner, the 2 middle ones are positive"
# Score 4 --> "top left, 2 bottom right ones are negative. all are negative in bottom left corner. bottom right corner, the middle one is positive and the one closest to the corner is positive"
# Score 5 --> "great job. you got all the positives. bottom left corner are all negative. 2 positives in top left corner and 3 positives in bottom right corner"
# Score 3 --> "good job, all positives again. there were 3 positives on the bottom left corner, 2 positives on the top left corner, and one positive on the top right corner"
# Score 4 --> "nice, you got the most positives possible! top left had 3, top right had 2, bottom right had 2"
# Score 4 --> "great job. 2 positives in bottom left, one positive in top left. the rest were negative"
# Score 5 --> "perfect. all were positive there. 3 pos in top right, one pos in bottom right and one pos in bottom left"
# Score 5 --> "great! you got all positives. there were 4 in top left and only one in bottom left"
#
# Context: partial, Complexity: 4
# Cumulative Score: 6
# 610019d78c4dbfa9d56317e5:610c0bb0cdf73476ce1dcd31
# Score 0 --> "the first shape you did was postive the second was negative "
# Score 0 --> "not alot going on there :) "
# Score 1 --> "that shape was positive More of those shapes "
# Score -1 --> "that shape was wrong avoid that shape "
# Score -1 --> "first one wrong, second shape was positive and third was negative "
# Score 2 --> "yes brilliant more of those shapes"
# Score 0 --> "to slow but on the right tracks "
# Score 2 --> "correct! more of those ones please!"
# Score 2 --> "yesss well done "
# Score 1 --> "lovely!"
#
# Context: full, Complexity: 4
# Cumulative Score: 39
# 61003733147e9217ad1e48bb:610c1b975473379ba5e383f6
# Score 1 --> "blue squares are positive and pink triangles "
# Score 5 --> "0.4 per square/triangle "
# Score 3 --> "blue triangles are negative "
# Score 4 --> "k "
# Score 5 --> "got max points "
# Score 3 --> "to the right had 3 points alsio "
# Score 4 --> "scored 4 points "
# Score 4 --> "+17p bonus"
# Score 5 --> "filled blue squares qive most bonus"
# Score 5 --> "good"
#
# Context: partial, Complexity: 4
# Cumulative Score: 1
# 61004220027f9e9dd7cfdd10:610c2580142a2c33fdf4b4bd
# Score 0 --> "green top green bottom "
# Score 0 --> "nan"
# Score -1 --> "nan"
# Score -3 --> "nan"
# Score -3 --> "change colour it needs to be green ones "
# Score 0 --> " "
# Score 2 --> "perfect "
# Score 2 --> "well done  "
# Score 2 --> "nan"
# Score 2 --> "great "
#
# Context: partial, Complexity: 1
# Cumulative Score: 35
# 61008916b6d0ba545c8521da:610c295f6c8b55acd87ff79f
# Score -2 --> "all but the last were negative. "
# Score 3 --> "good job! all positive :) "
# Score 4 --> "good job again! all were positive! "
# Score 4 --> "good job again!! all were positive! "
# Score 5 --> "great job again! all positive!! "
# Score 3 --> "all positive! good job!! "
# Score 4 --> "good job again! all positive! :) "
# Score 4 --> "great job once again! all positive! "
# Score 5 --> "you're doing great! all positive!! "
# Score 5 --> "amazing job!!! all positive! :) "
#
# Context: partial, Complexity: 1
# Cumulative Score: 27
# 6100c5312e56b24bcfcd2ed2:610c0f3eaf229930d11a3527
# Score -2 --> "red is bad"
# Score -5 --> "do not go to the red "
# Score 4 --> "good only go to the green "
# Score 4 --> "good, continue to only go to the green "
# Score 5 --> "continue to the same plan "
# Score 3 --> "good job, continue the same plan "
# Score 4 --> "good job, continue the same plan "
# Score 4 --> "good job, continue the same plan "
# Score 5 --> "good job, continue the plan just one more level "
# Score 5 --> "Good job "
#
# Context: full, Complexity: 4
# Cumulative Score: 37
# 610170d6ce2347d965a45cd7:610c1b9f2f7db193ef3e7cf8
# Score -2 --> "Good: Pink FILLED, Light Blue EDGE. Bad: Pink EDGE, Light Blue FILLED."
# Score 5 --> "Good job!"
# Score 4 --> "Good job!"
# Score 4 --> "Good job!"
# Score 5 --> "Good job!"
# Score 3 --> "Good job!"
# Score 4 --> "Good job!"
# Score 4 --> "Good job!"
# Score 5 --> "Good job!"
# Score 5 --> "Good job! "
#
# Context: partial, Complexity: 4
# Cumulative Score: 2
# 61019099ce876c08c5583037:610bf7f561845590ee597b1c
# Score 0 --> "that was a good try"
# Score 5 --> "NICE!!!"
# Score -1 --> "YIKES"
# Score -1 --> "I don't know what im suppose to be telling you"
# Score 1 --> "yea that upper right corner had all positive numbers"
# Score -3 --> "The numbers change every time "
# Score 1 --> "that was good. id say go for the bottom left corner next time"
# Score -1 --> "nice. now id say upper left"
# Score 5 --> "sweet possibly bottom right now?"
# Score -4 --> "dang "
#
# Context: partial, Complexity: 1
# Cumulative Score: 33
# 6102207794fe0360d19aaf46:610c132c39f5282ae3eef3e2
# Score 3 --> "Top left had 4 1s as well"
# Score 4 --> "Good Job. There was 1 more in that corner. "
# Score 3 --> "nice!"
# Score 3 --> "There you go! "
# Score 4 --> "Good Job.  "
# Score 1 --> "Alright! You will get them next time. They were pretty spread out. "
# Score 3 --> "Not bad! "
# Score 3 --> "Fantastic! There was one more in that right corner.  "
# Score 4 --> "Perfect! "
# Score 5 --> "Good Work! "
#
# Context: partial, Complexity: 4
# Cumulative Score: 6
# 61026015b70c93b95254a4ca:610ac6cd6bcd13f76a1fbe8c
# Score -2 --> "The most good ones are were in SW and NW and they were the opposite color that you chose."
# Score 1 --> "That was the right color this time...you were surrounded by good ones"
# Score 1 --> "SW had the most good ones....you chose the color correctly"
# Score 1 --> "NE had the most good ones"
# Score 0 --> "NE had all good ones."
# Score 0 --> "The first one was a good one...the second no."
# Score 1 --> "correct color"
# Score 1 --> "correct color"
# Score 2 --> "correct color...NW had all good ones."
# Score 1 --> "correct color...NE had 5 good ones"
#
# Context: full, Complexity: 1
# Cumulative Score: 14
# 6102b2123f073e595b65c933:610c132cb915f1255b37e917
# Score 2 --> "scored 2 points. Move down and to the left quicker"
# Score 2 --> "2 points. only hit one negative"
# Score -1 --> "-1 points "
# Score -3 --> "move up. the negative points are down below "
# Score 3 --> "great job! we got three points"
# Score -3 --> "negative again stick close to squares. stay away from triangles"
# Score 3 --> "awesome! once again, stay clear of triangles"
# Score 3 --> "great job! squares are good!"
# Score 3 --> "great work! same as before. squares=good"
# Score 5 --> "that was the best yet!"
#
# Context: partial, Complexity: 4
# Cumulative Score: -4
# 61032fba4a7140d0d8b4254b:610c0489fc1198f57f348aa0
# Score -3 --> "top left hand corner shape earns points"
# Score 2 --> "top right hand corner earns points"
# Score -1 --> "nan"
# Score 1 --> "top right hand corner"
# Score 5 --> "good job :) "
# Score -4 --> "bottom right hand corner shape earns points"
# Score 3 --> "great!"
# Score -2 --> "bottom right hand corner"
# Score -2 --> " screen keeps changing and not updated"
# Score -3 --> "thanks :) "
#
# Context: full, Complexity: 4
# Cumulative Score: 27
# 610335eae6a2b57fe716321e:610c048c9ac592a6cd23d030
# Score -3 --> "Pink triangles are positive"
# Score 1 --> "Solid pink triangles and open blue squares are positive"
# Score 2 --> "Positive: Open squares, solid triangles"
# Score 3 --> "Okay"
# Score 3 --> "Okay"
# Score 3 --> "Good"
# Score 4 --> "Good"
# Score 4 --> "Good"
# Score 5 --> "Good"
# Score 5 --> "Good"
#
# Context: full, Complexity: 1
# Cumulative Score: 36
# 610347b5b849c3e6a52e4a4a:610c132eb915f1255b37e918
# Score -3 --> "Collect solid shapes"
# Score 5 --> "Great job!"
# Score 4 --> "You are doing great!"
# Score 4 --> "Nice work! Keep going!!"
# Score 5 --> "Excellent!"
# Score 3 --> "You are doing great!"
# Score 4 --> "Just like that, keep going!"
# Score 4 --> "Perfect!"
# Score 5 --> "You are picking the best spots!"
# Score 5 --> "Wahoo!"
#
# Context: full, Complexity: 1
# Cumulative Score: 43
# 6106ea1c1626186c47bf74a7:610c0bb564f0d635480b6ead
# Score 4 --> "good job! the pink was good "
# Score 5 --> "good choice, the corner with the most pinks is best. "
# Score 4 --> "nice one :) "
# Score 4 --> "perfect "
# Score 5 --> "5/5 "
# Score 3 --> "you got this!"
# Score 4 --> "Wonderful strategy"
# Score 4 --> "excellent as usual"
# Score 5 --> "stunning performance"
# Score 5 --> "beautiful job, 10/10 thank you!"
#
# Context: partial, Complexity: 1
# Cumulative Score: 6
# 6106ed048e377ea870710a26:610c0f405b5d6873b0aa47f6
# Score 1 --> "nan"
# Score 2 --> "lower right were all positive"
# Score 0 --> "nan"
# Score -5 --> "nan"
# Score 1 --> "try top right "
# Score -3 --> "nan"
# Score 3 --> "nice "
# Score -3 --> "nan"
# Score 5 --> "good"
# Score 5 --> "nan"
#
# Context: full, Complexity: 1
# Cumulative Score: 34
# 6106fbbcd52909fe5cc2fc8e:610c215b64abd9ee4914b802
# Score 2 --> "GOOD JOB! WELL DONE. I LOV EYOU"
# Score 2 --> "SQUARES ARE GOOD TRIANGLES BAD "
# Score 1 --> "nice try, trying only going for the squares!"
# Score 3 --> "nice job, you chose the corner with the most squares. keep doing that, and avoid the triangles"
# Score 5 --> "perfect round. keep it up "
# Score 3 --> "another perfect round, great job"
# Score 4 --> "easy!! you chose the best corner. "
# Score 4 --> "i think we both got lucky that its only squares   its probably random but this is easy since all squares are good and triangles are bad. keep up the great work "
# Score 5 --> "cha ching, great job! 1 more level. "
# Score 5 --> "we almost had a perfect game. thanks for killing it. Enjoy your day (IM real btw, i hope you are too lol) "
#
# Context: partial, Complexity: 1
# Cumulative Score: 25
# 61075e88d4dee3669d2ecfc0:610c16d3949ae3884d5c7730
# Score -1 --> "all on bottom left are positive except for the one closest to corner the three closest to you right now are all positive top left corner are all positive except for the highest one on the right"
# Score 3 --> "all of the shapes in the corner you are in right now are positive all of the top right corner shapes are positive except the one closest to the center of the screen bottom left corner are all negative the only negative in the top left corner are the one closest to the corner and the bottom one on the left"
# Score 2 --> "everything in your current corner is positive except for the one closest to the corner bottom two shapes in the top left corner are negative middle two shapes in the top right corner are positive"
# Score 2 --> "good! you avoided the one negative in that corner bottom left corner shapes are all negative the two shapes furthest to the right in the top left corner are negative, the rest are positive"
# Score 2 --> "remember that you can click the up and right arrow at the same time to go diagonally, it will get you there faster all of the shapes in the corner you're in are positive all in bottom left corner are negative"
# Score 2 --> "shape closest to the corner in the section you're in is positive shape closest to center in top right corner is positive"
# Score 3 --> "bottom left corner are all positive except the one closest to center you got all of the positive in your current corner"
# Score 2 --> "top right corner are all negative the two shapes above you to the right are positive the two highest shapes in the bottom left corner are positive"
# Score 5 --> "yes!! those were all positive bottom right are all negative except the one on the top right the shape in the middle of all of the other shapes in the bottom left corner is positive"
# Score 5 --> "great job 👍🏻 best corner you could have picked"
#
# Context: full, Complexity: 4
# Cumulative Score: 27
# 61081550d87b8d059b0428f1:610ac6cb1d9cacb31c235eda
# Score -3 --> "."
# Score 3 --> "positives: pink empty triangle and square + blue full triangle and square  "
# Score 2 --> "positives: pink empty triangle and square + blue full triangle and square"
# Score 3 --> "positives: pink empty triangle and square + blue full triangle and square"
# Score 3 --> "positives: pink empty triangle and square + blue full triangle and square"
# Score 2 --> "."
# Score 3 --> "positives: pink empty triangle and square + blue full triangle and square"
# Score 4 --> "positives: pink empty triangle and square + blue full triangle and square"
# Score 5 --> "positives: pink empty triangle and square + blue full triangle and square"
# Score 5 --> "good job"
#
# Context: full, Complexity: 1
# Cumulative Score: 42
# 61084547f7d160a9f35c6aa7:610c16cd3a0300d2bf14f84e
# Score 3 --> "all triangles are positive "
# Score 5 --> "well done! :) "
# Score 4 --> ":)"
# Score 4 --> ":) good job"
# Score 5 --> ":) "
# Score 3 --> "doing well "
# Score 4 --> "all triangles are still positive :)"
# Score 4 --> ":)"
# Score 5 --> "nice :)"
# Score 5 --> "good job :)"
#
# Context: partial, Complexity: 1
# Cumulative Score: 28
# 610acc7e893f0c61f5cc0e72:610c048d4a4aa6701ff9920b
# Score -2 --> "top left bottom 3"
# Score 0 --> "top right 4 not lower one"
# Score 4 --> "top right, the 2 in the middle"
# Score 4 --> "3 at top left most "
# Score 2 --> "other 3 closest to you"
# Score 2 --> "bottom right, first 2 closet to you on left"
# Score 4 --> "top left, 2 on top, and one in between lower ones "
# Score 4 --> "bottom left, the 2 on top"
# Score 5 --> "top right, closest to you, then one in the middle"
# Score 5 --> "All in top left corner except lower right one"

# %%
print("Manually identified \"bad\" teachers:")

for k, games in chat_games.groupby("task_uuid"):
    
    if np.all(games.bad_teacher):

        games = games.sort_values(by='level_number')
        print("\nContext: {}, Complexity: {}\nCumulative Score: {}".format(games.iloc[0]["Context"], games.iloc[0]["boolean_complexity"], games.iloc[-1]["cum_player_score"]))
        print("{}".format(k))
        for gid, g in games.iterrows():
            print("Score {} --> \"{}\"".format(g.player_score, g.chat_text.replace("|", " ")))
# Out:
# Manually identified "bad" teachers:
#
# Context: partial, Complexity: 1
# Cumulative Score: 8
# 59bd3c6e3a9ab60001119ae5:610c0badfc8dd2f9b3f6ca85
# Score 3 --> "Always try to move towards the positive number as quickly as possible."
# Score 2 --> "Good job, but always to avoid the negative digits."
# Score 0 --> "The performance was terrible. Better luck next time."
# Score 3 --> "You reacted very slowly. Poor performance. "
# Score 1 --> "The totally tally for this stage is very discouraging. I will suggest you start from your top right hand corner in the next stage."
# Score -3 --> "Yet another terrible performance."
# Score 3 --> "Great improvement. very commendable."
# Score -1 --> "Another disappointing performance. Always aim for the green number, move towards the direction where we have more green numbers."
# Score 4 --> "Great improvement."
# Score -4 --> "I'm a little bit disappointed but then overall you've tried."
#
# Context: full, Complexity: 4
# Cumulative Score: 13
# 59dc458f77860e000151240e:610bf7f5222bf6d078c41663
# Score -3 --> "nan"
# Score 4 --> "nan"
# Score 2 --> "nan"
# Score 2 --> "nan"
# Score -4 --> "Hi "
# Score 1 --> "nan"
# Score 3 --> "nan"
# Score 2 --> "nan"
# Score 3 --> "nan"
# Score 3 --> "nan"
#
# Context: partial, Complexity: 4
# Cumulative Score: 17
# 5ca9f8926025570001c872f3:610c048b79afad201974a45d
# Score -3 --> "Nice try"
# Score 2 --> "You are doing great"
# Score 2 --> "nan"
# Score 2 --> "Doing great!"
# Score 2 --> "nan"
# Score 1 --> "nan"
# Score 3 --> "Great score!!!!"
# Score 2 --> "nan"
# Score 3 --> "One more level to go!!!"
# Score 3 --> "WOW!!!!"
#
# Context: full, Complexity: 4
# Cumulative Score: 22
# 5ce7c46d79642d0017767d94:610c1b9a3ebc4299d4805b61
# Score 1 --> "It's  not easy to do much in the time allowed.   We will do well next round. "
# Score 2 --> "2 points well done. "
# Score 2 --> "2 more points. keep going. "
# Score 3 --> "3 Points that round. "
# Score 2 --> "2 points. we are doing well "
# Score 2 --> "2 more points. We are winning. "
# Score 2 --> "" more points. "
# Score 2 --> "Seems to be 2 points every round. "
# Score 3 --> "3 that round"
# Score 3 --> "3 points. well done.  "
#
# Context: partial, Complexity: 1
# Cumulative Score: -1
# 5d8cef3c28e183001a335ab0:610ad45a8d158e1bfb034b8d
# Score 2 --> "Cool! "
# Score 2 --> "nan"
# Score 0 --> "nan"
# Score -4 --> "nan"
# Score -1 --> "Almost! "
# Score 0 --> "Almost!"
# Score 2 --> "Yay!"
# Score 2 --> "Yay!"
# Score -2 --> "Aww"
# Score -2 --> "Good try!"
#
# Context: partial, Complexity: 1
# Cumulative Score: 28
# 5e8e11676c1dea0be7a64cb3:610bfd2297422a184d69b7ee
# Score 0 --> "boxes with 1 are the positive ones"
# Score 3 --> "great"
# Score 1 --> "average"
# Score -2 --> "top r"
# Score 5 --> "top right"
# Score 3 --> "nice"
# Score 4 --> "niceee"
# Score 4 --> "great"
# Score 5 --> "beautiful"
# Score 5 --> "niceeee"
#
# Context: partial, Complexity: 4
# Cumulative Score: 14
# 5f9b3b52d60a821cf75f52de:610c1b9e3fa3b8c008a75f39
# Score -2 --> "That was a nice try! "
# Score 4 --> "Dang way to go that was nice! "
# Score 2 --> "good job! "
# Score 2 --> "way to go! "
# Score 0 --> " "
# Score -4 --> "that was a nice try! "
# Score 3 --> "great job!  "
# Score 2 --> "great job!  "
# Score 3 --> "Wow you're a pro "
# Score 4 --> "that was awesome! "
#
# Context: partial, Complexity: 4
# Cumulative Score: -4
# 606ee8f52a168c78fda80c23:610c048b017e4dde1bbf303d
# Score 2 --> "one more inthatcorner"
# Score 2 --> "good job"
# Score 0 --> "go down next time"
# Score -2 --> "ugh it switched up go down again"
# Score -2 --> "it knows qhat im saying ugh go up"
# Score 0 --> "send it"
# Score 0 --> "idek"
# Score 0 --> "omg"
# Score -3 --> "yay"
# Score -1 --> "stay up"
#
# Context: partial, Complexity: 4
# Cumulative Score: 10
# 60da1c98d7b33bcfad762350:610c13303e50917e1302aa39
# Score 0 --> "  "
# Score -2 --> "take the green ones"
# Score 0 --> "   "
# Score -2 --> "nan"
# Score 2 --> " "
# Score 2 --> "   "
# Score 3 --> "   "
# Score 1 --> "  "
# Score 3 --> "   "
# Score 3 --> " "
#
# Context: partial, Complexity: 4
# Cumulative Score: 5
# 60fcad10ce60a71810f7f549:610c0f3cd0c6cd80029b68f1
# Score 1 --> "Left sides seem better."
# Score -2 --> "Maybe bottom right then"
# Score 1 --> "try the blue"
# Score -2 --> "try up right"
# Score 3 --> "same again"
# Score -3 --> "down left"
# Score 1 --> "take a guess"
# Score 2 --> "lower corner ones seem better overall"
# Score 2 --> "up left"
# Score 2 --> "last one it seems"
#
# Context: full, Complexity: 4
# Cumulative Score: 14
# 60fd5daeed5bbfc18254753e:610c1329e9112cf1024c014f
# Score 1 --> "nan"
# Score 0 --> "nan"
# Score 1 --> "nan"
# Score 4 --> "nan"
# Score -1 --> "nan"
# Score 2 --> " "
# Score 3 --> "nan"
# Score -1 --> "nan"
# Score 2 --> "nan"
# Score 3 --> "nan"
#
# Context: partial, Complexity: 4
# Cumulative Score: 2
# 60fd734292d9cde95206671f:610c0baf5a42b3d64d1865bb
# Score -3 --> "No worries"
# Score 2 --> "Nice"
# Score 0 --> "Nice"
# Score -5 --> "Now I know this isn't a real person. Knew when I saw the board that he/she would go straight for the bottom left"
# Score -1 --> "Okay"
# Score 1 --> "Nice"
# Score -1 --> "Keep going"
# Score -1 --> "Nice"
# Score 5 --> "Coolio"
# Score 5 --> "Redeemed yourself"
#
# Context: partial, Complexity: 1
# Cumulative Score: -5
# 60feb9af1d56359bd85bb83f:610c132edb40da909b380020
# Score 0 --> "Good try."
# Score 3 --> "Good start  "
# Score 0 --> "Good try"
# Score 1 --> "You are doing great!"
# Score -5 --> "Oops, wrong direction."
# Score 0 --> "Better luck next time."
# Score -2 --> "Oops, you're still great!"
# Score -1 --> "We  We'll get 'em next time."
# Score -2 --> "We will do better next time."
# Score 1 --> "Good start."
#
# Context: partial, Complexity: 1
# Cumulative Score: -15
# 60fec3441bfba411416b4925:610bfd1f790a54768b6cd9ed
# Score -2 --> "shapes bottom left "
# Score 1 --> "bottom right"
# Score -1 --> "go right "
# Score -3 --> "bad luck "
# Score 0 --> "green is positive"
# Score -4 --> "bad luck"
# Score -2 --> "try again"
# Score -3 --> "Bad luck"
# Score -4 --> "good try"
# Score 3 --> "well done"
#
# Context: partial, Complexity: 4
# Cumulative Score: 1
# 61004220027f9e9dd7cfdd10:610c2580142a2c33fdf4b4bd
# Score 0 --> "green top green bottom "
# Score 0 --> "nan"
# Score -1 --> "nan"
# Score -3 --> "nan"
# Score -3 --> "change colour it needs to be green ones "
# Score 0 --> " "
# Score 2 --> "perfect "
# Score 2 --> "well done  "
# Score 2 --> "nan"
# Score 2 --> "great "
#
# Context: partial, Complexity: 1
# Cumulative Score: 27
# 6100c5312e56b24bcfcd2ed2:610c0f3eaf229930d11a3527
# Score -2 --> "red is bad"
# Score -5 --> "do not go to the red "
# Score 4 --> "good only go to the green "
# Score 4 --> "good, continue to only go to the green "
# Score 5 --> "continue to the same plan "
# Score 3 --> "good job, continue the same plan "
# Score 4 --> "good job, continue the same plan "
# Score 4 --> "good job, continue the same plan "
# Score 5 --> "good job, continue the plan just one more level "
# Score 5 --> "Good job "
#
# Context: partial, Complexity: 4
# Cumulative Score: 2
# 61019099ce876c08c5583037:610bf7f561845590ee597b1c
# Score 0 --> "that was a good try"
# Score 5 --> "NICE!!!"
# Score -1 --> "YIKES"
# Score -1 --> "I don't know what im suppose to be telling you"
# Score 1 --> "yea that upper right corner had all positive numbers"
# Score -3 --> "The numbers change every time "
# Score 1 --> "that was good. id say go for the bottom left corner next time"
# Score -1 --> "nice. now id say upper left"
# Score 5 --> "sweet possibly bottom right now?"
# Score -4 --> "dang "

# %% [markdown]
# ## Demonstrative Teaching

# %%
import json
demos_to_analyze = pd.read_csv("data/exp2_demonstrations.csv")

demos_to_analyze.game = demos_to_analyze.game.apply(lambda x: json.loads(x.replace("\'", "\"")))

# %% [markdown]
# # Visualize individual level

# %%
def plot_control(object_list, **kwargs):
    return plot_object_layout(object_list, ['r', 'w', 'g'], 
                              positive_shape="s", label_values="true_value", plot_fake_colors=False, max_obj_value=1,
                              **kwargs)

def plot_object_layout(original_object_list, object_colormap, positive_shape='o', negative_shape='s', zero_shape=None, 
                       color_magnitude=False, plot_x=5, plot_y=5, title="", label_values=None, max_obj_value=10, plot_fake_colors=True, ax=None):    

    object_list = copy.deepcopy(original_object_list)
    
    for o in object_list:
        o["true_value"] = o.get('value')

    objects_df = pd.DataFrame(object_list)
    
    if ax is None:
        plt.figure(figsize=(plot_x, plot_y))
        ax = plt.gca()
    
    ax.set_facecolor('w')
    ax.scatter(objects_df.x, objects_df.y, s=400, 
               marker='s', color=(.6, .6, .6), edgecolors='white', linewidths=1)
    
    if label_values:
        neg_objects = objects_df[objects_df.true_value < 0]
        for index, row in neg_objects.iterrows():
            ax.text(row["x"]-1, row["y"]+.75, 
                    int(row[label_values]), 
                    weight='bold', c=(1,.2,.2))
            
        pos_objects = objects_df[objects_df.true_value > 0]
        for index, row in pos_objects.iterrows():
            ax.text(row["x"]-1, row["y"]+.75, 
                    int(row[label_values]), 
                    weight='bold', c=(.2,1,.2))
                
    ax.set_xlim(0, 75)
    ax.set_ylim(75,0)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title(title)
    ax.axis("off")

# %%
def get_viz_string(object_dict, class_features):
    
    pos_features = set(class_features[1])
    neg_features = set(class_features[-1])
    
    return class_features[object_dict["value"]][object_dict["mask_value"]]

def update_object_with_mask(object_dict, class_features):
    
    string = get_viz_string(object_dict, class_features)
    
    color = 'm' if string[0] == '1' else 'c'
    shape = '^' if string[1] == '1' else 's'
    hollow = True if string[2] == '1' else False
    
    object_dict.update({"color": color, "shape": shape, "hollow": hollow})
    
    return object_dict


def plot_boolean_colors(original_object_list, class_features,
                        plot_x=5, plot_y=5, title="", label_values=False, ax=None):    

    if ax is None:
        ax = plt.figure(figsize=(plot_x, plot_y)).gca()
    
    object_list = copy.deepcopy(original_object_list)
    object_list = [update_object_with_mask(o, class_features) for o in object_list]
    objects_df = pd.DataFrame(object_list)
    
    ax.set_facecolor('w')
        
    for s, df in objects_df[objects_df.hollow == False].groupby("shape"):
        ax.scatter(df.x, df.y, s=400, 
                    marker=s,
                    color=df.color.values)
    
    for s, df in objects_df[objects_df.hollow == True].groupby("shape"):
        ax.scatter(df.x, df.y, s=400, marker=s,
                   edgecolors=df.color.values,
                   facecolors='none',
                  linewidths=4)
                
    ax.set_xlim(0, 75)
    ax.set_ylim(75,0)
    ax.set_xticks([])
    ax.set_yticks([])
    
    ax.set_title(title)
    ax.axis("off")

# %%
import copy

level_to_plot = 2
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

CLASS_TWO_FEATURES = {
    1: [ "011", "100", "001", "110"],
    -1:["000",  "111", "010",  "101"]}

ALL_FEATURES = set(''.join(s) for s in itertools.product('01', repeat=3))

for ax, viz in zip(axs.reshape(-1), ["full", "partial"]):
    
    all_games_on_level = demos_to_analyze[demos_to_analyze.level_number == level_to_plot]
    
    matched = all_games_on_level.apply(lambda x: x.game["task_configuration"]["visibility"] == viz, axis=1)
    viz_matched_games = all_games_on_level[matched]
    
    for g in viz_matched_games.game:
        trajectory = g['player_locations']
        ts = [t[0] for t in trajectory]
        x = [t[1] for t in trajectory]
        y = [t[2] for t in trajectory]

        ax.scatter(x, y, c=ts, cmap='Greys', alpha=.2)
        plt.gca().set_title(viz)
    
    if viz == 'partial':
        plot_control(viz_matched_games.game.iloc[0]["config"]["frame_data"]["objects"], ax=ax)
    else:
        plot_boolean_colors(viz_matched_games.game.iloc[0]["config"]['frame_data']['objects'], class_features=CLASS_TWO_FEATURES, ax=ax)
